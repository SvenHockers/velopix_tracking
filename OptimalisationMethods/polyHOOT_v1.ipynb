# %%
import os 
import sys
import json
sys.path.append(os.path.abspath(".."))
from velopix_wrappers.optimizers import BaseOptimizer
from velopix_wrappers.velopix_pipeline import TrackFollowingPipeline, GraphDFSPipeline, SearchByTripletTriePipeline
from typing import Any, Dict
import numpy as np

from typing import Any, Dict, Literal, List
import random
import numpy as np
from velopix_wrappers.optimizers import BaseOptimizer, pMap
from copy import deepcopy

# %%
class Node(object):
    def __init__(self, bounds, parent: Any = None):
        self.sum_reward = 0
        self.visited = 0
        self.children = []
        self.parent = parent
        self.bounds = bounds

    def add_child(self, child: Any):
        self.children.append(child)

# %%
class PolyHoot(BaseOptimizer):
    def __init__(
        self,
        alfa,
        eta,
        epsilon,
        max_iterations: int = 100,
        objective: Literal["min", "max"] = "min",
        weights: list[float]=[1.0, 1.0, 1.0, -10.0]
    ):
        super().__init__(objective=objective, auto_eval={"autoEval": True, "nested": True, "weights": weights})
        self.max_iterations = max_iterations
        self.current_iteration = 0
        self.alfa = alfa
        self.epsilon = epsilon
        self.eta = eta


    def init(self) -> pMap:
        """
        Initializes with a random point within bounds.
        """

        self.best_score = 0


        self.cfg = self._algorithm.get_config()
        self.bounds = self._algorithm.get_bounds()

        self.root = Node(bounds=self.bounds)  # Root node with no bounds
        self.nodes = [self.root]
        self.current_node = self.root

        self.param_num = 0

        for key, (typ, _) in self.cfg.items():
            if typ is not bool:
                self.param_num += 1

        self.nu = 4 * self.param_num
        self.ro = 1 / (4 * self.param_num)



        
        self.current_iteration += 1

        #pregenerate trees of bounds
        for key, (typ, _) in self.cfg.items():
            if typ is bool:
                current_leaves = [node for node in self.nodes if len(node.children) == 0]
                for node in current_leaves: #NOTE: I think this is an infite loop no since we keep adding nodes to the nodes list in the loop we keep adding children forever no?
                    #also changed logic since we were overriding the original bounds. (unless you changed it already then no, since current leaves is a copy of the current nodes)
                    bounds_false = deepcopy(node.bounds)
                    bounds_false[key] = False #TODO should this be an int or a true bool to ask group.. (changing  it to bool)
                    node1 = Node(bounds=bounds_false, parent=node)
                    
                    bounds_true = deepcopy(node.bounds)
                    bounds_true[key] = True #TODO should this be an int or a true bool to ask group..
                    node2 = Node(bounds=bounds_true, parent=node)
                    
                    #I think we also want to add these as children to the parent node yeah? or in this case the current node (yes indeed)
                    node.children.append(node1)
                    node.children.append(node2)
                    
                    #leave unchanged.. (I don't think we ever use the node list again, but just in case)
                    self.nodes.append(node1)
                    self.nodes.append(node2)


        self.current_node = self.root
        depth = 0

        while len(self.current_node.children):
            self.current_node.visited += 1
            self.current_node = node.children[0]
            depth += 1


        self.current_node.visited += 1

        new_bounds = self.returnBounds(self.current_node.bounds)

        self.current_node.add_child(Node(bounds=new_bounds[0], parent=self.current_node))
        self.current_node.add_child(Node(bounds=new_bounds[1], parent=self.current_node))


        pmap = self.returnPmap(self.current_node.bounds)

        # print(f"Bounds: {self.current_node.bounds}\n pmap: {pmap}\n")

        return pmap
    


    def next(self) -> pMap:
        """
        Evaluates the current configuration and returns a new one.
        """
        self.current_iteration += 1


        # Evaluate the current configuration (from previous init/next call)
        #score = self.objective_func([1.0, 1.0, 1.0, -10.0])
        #so we already increased the count of the nodes but we still want to backprop the scors which should happen after a run so at the start of 
        # next we get the last score in history and trace back up the stack accordingly or just use the score above but faster to get the score from history??? TODO ask team
        #TODO:backprop here FIXED?!?!
        if hasattr(self, 'score_history') and len(self.score_history) > 0:
            score = self.score_history[-1]
            # print(score)
            current = self.current_node
            while current is not None:
                current.sum_reward += score
                current = current.parent
        
        
        # print(f"score: {self.current_node.sum_reward}\n")

        if self.current_node.sum_reward < self.best_score:
            self.best_score = self.current_node.sum_reward
        
        node = self.root
        depth = 0



        while len(node.children):
            node.visited += 1
            if node.children[0].visited == 0:
                node = node.children[0]
            elif node.children[1].visited == 0:
                node = node.children[1]
            else:
                node1_score = (-node.children[0].sum_reward / node.children[0].visited) + (self.current_iteration ** (self.alfa/self.epsilon)) * (node.children[0].visited ** (self.eta - 1)) + (self.nu * (self.ro ** depth))
                node2_score = (-node.children[1].sum_reward / node.children[1].visited) + (self.current_iteration ** (self.alfa/self.epsilon)) * (node.children[1].visited ** (self.eta - 1)) + (self.nu * (self.ro ** depth))

                if node1_score > node2_score:
                    node = node.children[0]
                else:
                    node = node.children[1]

            depth += 1

        node.visited += 1

        new_bounds = self.returnBounds(node.bounds)

        node.add_child(Node(bounds=new_bounds[0], parent=node))
        node.add_child(Node(bounds=new_bounds[1], parent=node))


        pmap = self.returnPmap(node.bounds)
        #keep track of the leaf node we expanded and rolled out for the backprop we we do next again.
        self.current_node = node

        # print(f"Bounds: {self.current_node.bounds}\n pmap: {pmap}\n")
            
        return pmap
    

    def is_finished(self) -> bool:
        """Determines if optimization is complete."""
        #TODO: possibly add a check for reaching target score
        #TODO check with team but I think here we also want to perform backprop since if were finished we wont performn the last next we need to backprop so we do it here instead (maybe, depends when this function is called by the pipeline(TODO: check it), either way, if we don't it would just mean we skip the last iteration, which should not be that big of a problem)
        finished = self.current_iteration >= self.max_iterations
        if finished:
            if hasattr(self, 'score_history') and len(self.score_history) > 0:
                score = self.score_history[-1]
                current = self.current_node
                while current is not None:
                    current.sum_reward += score
                    current = current.parent


        print(f"score: {self.best_score}\n")
                
        return finished
    

    #return pmap based on bounds (split in middle) (rollout phase)
    def returnPmap (self, bounds: Dict[str, Any]) -> Dict[str, Any]:
        new_pmap = {}
        
        for key, (typ, _) in self.cfg.items():
            if typ is float:
                new_pmap[key] = (bounds[key][0] + bounds[key][1]) / 2
            elif typ is int:
                new_pmap[key] = (int)((bounds[key][0] + bounds[key][1]) / 2)
            elif typ is bool:
                new_pmap[key] = bounds[key]
            
        return new_pmap


    def returnBounds(self, bounds: Dict[str, Any]) -> List [Dict[str, Any]]: #TODO we currently split each of the bounds in half but we only want to split the axis with the 
                                                                                            # currently largest diameter (yes, should be done)

                                                                                            # also its late my brain is cooked but should we skip over the keys that 
                                                                                            # are boolean as we currently try to split these? (I added that now, just in case)

                                                                                            # we also never noremalize anywhere. (will do that after lunch, will be done impleicetly (how do you write that?) when calculating biggest bound)

        map = self.returnPmap(bounds)
        new_bounds = [deepcopy(bounds), deepcopy(bounds)]

        
        # find biggest bound
        max_key = None
        max_relative_diff = -1

        for key, (typ, _) in self.cfg.items():
            if typ is not bool:
                original_range = self.bounds[key][1] - self.bounds[key][0]
                current_range = bounds[key][1] - bounds[key][0]
                relative_diff = current_range / original_range if original_range != 0 else 0

                if relative_diff > max_relative_diff:
                    max_relative_diff = relative_diff
                    max_key = key

        # Split only the key with the biggest relative size
        if max_key is not None:
            low, high = new_bounds[0][max_key]
            new_bounds[0][max_key] = (low, map[max_key])

            low, high = new_bounds[1][max_key]
            new_bounds[1][max_key] = (map[max_key], high)

            
        return new_bounds

# %%
events = []
n_files = 150

for i in range(0, n_files):
    if i == 51:
        """
        There's an issue with event 51 -> module_prefix_sum contains value 79 twice resulting in and indexing error when loading the event
        """
        print(f"Skipping problematic file: velo_event_{i}.json")
    else:    
        print(f"Loading file: velo_event_{i}.json")
        event_file = open(os.path.join("../DB/raw", f"velo_event_{i}.json"))
        json_data = json.loads(event_file.read())
        events.append(json_data) # type: ignore
        event_file.close()
# Out:
# Loading file: velo_event_0.json
# Loading file: velo_event_1.json
# Loading file: velo_event_2.json
# Loading file: velo_event_3.json
# Loading file: velo_event_4.json
# Loading file: velo_event_5.json
# Loading file: velo_event_6.json
# Loading file: velo_event_7.json
# Loading file: velo_event_8.json
# Loading file: velo_event_9.json
# Loading file: velo_event_10.json
# Loading file: velo_event_11.json
# Loading file: velo_event_12.json
# Loading file: velo_event_13.json
# Loading file: velo_event_14.json
# Loading file: velo_event_15.json
# Loading file: velo_event_16.json
# Loading file: velo_event_17.json
# Loading file: velo_event_18.json
# Loading file: velo_event_19.json
# Loading file: velo_event_20.json
# Loading file: velo_event_21.json
# Loading file: velo_event_22.json
# Loading file: velo_event_23.json
# Loading file: velo_event_24.json
# Loading file: velo_event_25.json
# Loading file: velo_event_26.json
# Loading file: velo_event_27.json
# Loading file: velo_event_28.json
# Loading file: velo_event_29.json
# Loading file: velo_event_30.json
# Loading file: velo_event_31.json
# Loading file: velo_event_32.json
# Loading file: velo_event_33.json
# Loading file: velo_event_34.json
# Loading file: velo_event_35.json
# Loading file: velo_event_36.json
# Loading file: velo_event_37.json
# Loading file: velo_event_38.json
# Loading file: velo_event_39.json
# Loading file: velo_event_40.json
# Loading file: velo_event_41.json
# Loading file: velo_event_42.json
# Loading file: velo_event_43.json
# Loading file: velo_event_44.json
# Loading file: velo_event_45.json
# Loading file: velo_event_46.json
# Loading file: velo_event_47.json
# Loading file: velo_event_48.json
# Loading file: velo_event_49.json
# Loading file: velo_event_50.json
# Skipping problematic file: velo_event_51.json
# Loading file: velo_event_52.json
# Loading file: velo_event_53.json
# Loading file: velo_event_54.json
# Loading file: velo_event_55.json
# Loading file: velo_event_56.json
# Loading file: velo_event_57.json
# Loading file: velo_event_58.json
# Loading file: velo_event_59.json
# Loading file: velo_event_60.json
# Loading file: velo_event_61.json
# Loading file: velo_event_62.json
# Loading file: velo_event_63.json
# Loading file: velo_event_64.json
# Loading file: velo_event_65.json
# Loading file: velo_event_66.json
# Loading file: velo_event_67.json
# Loading file: velo_event_68.json
# Loading file: velo_event_69.json
# Loading file: velo_event_70.json
# Loading file: velo_event_71.json
# Loading file: velo_event_72.json
# Loading file: velo_event_73.json
# Loading file: velo_event_74.json
# Loading file: velo_event_75.json
# Loading file: velo_event_76.json
# Loading file: velo_event_77.json
# Loading file: velo_event_78.json
# Loading file: velo_event_79.json
# Loading file: velo_event_80.json
# Loading file: velo_event_81.json
# Loading file: velo_event_82.json
# Loading file: velo_event_83.json
# Loading file: velo_event_84.json
# Loading file: velo_event_85.json
# Loading file: velo_event_86.json
# Loading file: velo_event_87.json
# Loading file: velo_event_88.json
# Loading file: velo_event_89.json
# Loading file: velo_event_90.json
# Loading file: velo_event_91.json
# Loading file: velo_event_92.json
# Loading file: velo_event_93.json
# Loading file: velo_event_94.json
# Loading file: velo_event_95.json
# Loading file: velo_event_96.json
# Loading file: velo_event_97.json
# Loading file: velo_event_98.json
# Loading file: velo_event_99.json
# Loading file: velo_event_100.json
# Loading file: velo_event_101.json
# Loading file: velo_event_102.json
# Loading file: velo_event_103.json
# Loading file: velo_event_104.json
# Loading file: velo_event_105.json
# Loading file: velo_event_106.json
# Loading file: velo_event_107.json
# Loading file: velo_event_108.json
# Loading file: velo_event_109.json
# Loading file: velo_event_110.json
# Loading file: velo_event_111.json
# Loading file: velo_event_112.json
# Loading file: velo_event_113.json
# Loading file: velo_event_114.json
# Loading file: velo_event_115.json
# Loading file: velo_event_116.json
# Loading file: velo_event_117.json
# Loading file: velo_event_118.json
# Loading file: velo_event_119.json
# Loading file: velo_event_120.json
# Loading file: velo_event_121.json
# Loading file: velo_event_122.json
# Loading file: velo_event_123.json
# Loading file: velo_event_124.json
# Loading file: velo_event_125.json
# Loading file: velo_event_126.json
# Loading file: velo_event_127.json
# Loading file: velo_event_128.json
# Loading file: velo_event_129.json
# Loading file: velo_event_130.json
# Loading file: velo_event_131.json
# Loading file: velo_event_132.json
# Loading file: velo_event_133.json
# Loading file: velo_event_134.json
# Loading file: velo_event_135.json
# Loading file: velo_event_136.json
# Loading file: velo_event_137.json
# Loading file: velo_event_138.json
# Loading file: velo_event_139.json
# Loading file: velo_event_140.json
# Loading file: velo_event_141.json
# Loading file: velo_event_142.json
# Loading file: velo_event_143.json
# Loading file: velo_event_144.json
# Loading file: velo_event_145.json
# Loading file: velo_event_146.json
# Loading file: velo_event_147.json
# Loading file: velo_event_148.json
# Loading file: velo_event_149.json

# %%
pipeline = SearchByTripletTriePipeline(events=events, intra_node=True) # type: ignore

# %%
Optimiser = PolyHoot(max_iterations=3, objective="min", weights=[0.4, 0.2, 0.5, -7.0], alfa=6, eta=3, epsilon=10) # type: ignore
optimal_parameters = pipeline.optimise_parameters(Optimiser, max_runs=1000) # DO NOT remove max_runs, chances are that this will run forever
# Out:
# Optimising:   0%|          | 1/1000 [00:01<27:55,  1.68s/it]
# === Objective Function Debug Info ===
# time_rate: 0.6982319355010986
# ghost_rate: 46.264244060852256
# num_tracks: 85913
# penalty: 0
# weights: [0.4, 0.2, 0.5, -7.0]
# nested: True
# clone_rate: 2.5294441899266245
# terms (used in weighted sum): (0.6982319355010986, np.float64(2.5294441899266245), 46.264244060852256, 85913)
# score (with penalty): -601367.0826963574
# score: -601367.0826963574
#
# === Objective Function Debug Info ===
# time_rate: 0.6964550018310547
# ghost_rate: 37.43027197266928
# num_tracks: 74934
# penalty: 0
# weights: [0.4, 0.2, 0.5, -7.0]
# nested: True
# Optimising:   0%|          | 2/1000 [00:03<28:07,  1.69s/it]
# clone_rate: 2.6589630965404
# terms (used in weighted sum): (0.6964550018310547, np.float64(2.6589630965404), 37.43027197266928, 74934)
# score (with penalty): -524518.4744893936
# score: -601367.0826963574
#
# === Objective Function Debug Info ===
# time_rate: 0.8743531703948975
# ghost_rate: 50.66330924272649
# num_tracks: 91737
# penalty: 0
# weights: [0.4, 0.2, 0.5, -7.0]
# nested: True
# Optimising:   0%|          | 3/1000 [00:05<31:16,  1.88s/it]
# clone_rate: 2.533860259331406
# terms (used in weighted sum): (0.8743531703948975, np.float64(2.533860259331406), 50.66330924272649, 91737)
# score (with penalty): -642132.8118320586
# score: -642132.8118320586
#
# Finsihed condition met, exiting...

# %%
Optimiser.history
# Out:
# {'7565c058-3c28-45f1-8614-69422701c214': {'params': {},
#   'score': np.float64(-601367.0826963574),
#   'meta': {'total_tracks': 85913,
#    'total_ghosts': 39747,
#    'overall_ghost_rate': 46.264244060852256,
#    'event_avg_ghost_rate': 40.49136947750126,
#    'categories': [{'label': 'velo',
#      'n_reco': 39696,
#      'n_particles': 42418,
#      'recoeffT': 93.58291291432882,
#      'avg_recoeff': 93.58291291432882,
#      'n_clones': 1410,
#      'clone_percentage': 3.551995163240629,
#      'purityT': 98.37139780657667,
#      'avg_purity': 98.1540991902834,
#      'avg_hiteff': 97.6368404986826,
#      'hit_eff_percentage': 96.46731007717716},
#     {'label': 'long>5GeV',
#      'n_reco': 7631,
#      'n_particles': 7746,
#      'recoeffT': 98.51536276788019,
#      'avg_recoeff': 98.5153627678802,
#      'n_clones': 242,
#      'clone_percentage': 3.1712750622461012,
#      'purityT': 98.23008075092194,
#      'avg_purity': 99.10714285714286,
#      'avg_hiteff': 98.1436420722135,
#      'hit_eff_percentage': 96.62817555630474},
#     {'label': 'long_strange',
#      'n_reco': 563,
#      'n_particles': 584,
#      'recoeffT': 96.4041095890411,
#      'avg_recoeff': 96.4041095890411,
#      'n_clones': 16,
#      'clone_percentage': 2.841918294849023,
#      'purityT': 97.44502366604904,
#      'avg_purity': 91.39730639730641,
#      'avg_hiteff': 88.88888888888889,
#      'hit_eff_percentage': 97.36105120172478},
#     {'label': 'long_strange>5GeV',
#      'n_reco': 264,
#      'n_particles': 272,
#      'recoeffT': 97.05882352941177,
#      'avg_recoeff': 97.05882352941177,
#      'n_clones': 9,
#      'clone_percentage': 3.409090909090909,
#      'purityT': 97.42914872758715,
#      'avg_purity': 91.26262626262626,
#      'avg_hiteff': 100.0,
#      'hit_eff_percentage': 97.05805946190561},
#     {'label': 'long_fromb>5GeV',
#      'n_reco': 538,
#      'n_particles': 550,
#      'recoeffT': 97.81818181818181,
#      'avg_recoeff': 97.81818181818181,
#      'n_clones': 10,
#      'clone_percentage': 1.858736059479554,
#      'purityT': 97.6653114495903,
#      'avg_purity': 100.0,
#      'avg_hiteff': 100.0,
#      'hit_eff_percentage': 96.54082764686058},
#     {'label': 'long',
#      'n_reco': 12085,
#      'n_particles': 12300,
#      'recoeffT': 98.2520325203252,
#      'avg_recoeff': 98.2520325203252,
#      'n_clones': 385,
#      'clone_percentage': 3.1857674803475384,
#      'purityT': 98.2338719993261,
#      'avg_purity': 98.41865451621548,
#      'avg_hiteff': 98.55802733851516,
#      'hit_eff_percentage': 96.37326579494085},
#     {'label': 'long_fromb',
#      'n_reco': 672,
#      'n_particles': 689,
#      'recoeffT': 97.53265602322206,
#      'avg_recoeff': 97.53265602322206,
#      'n_clones': 12,
#      'clone_percentage': 1.7857142857142858,
#      'purityT': 97.84021789249638,
#      'avg_purity': 100.0,
#      'avg_hiteff': 100.0,
#      'hit_eff_percentage': 96.80960423704377}],
#    'events': {'1': [{'label': 'long_fromb>5GeV',
#       'n_reco': 3,
#       'n_particles': 3,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 94.44444444444446,
#       'avg_purity': 94.44444444444446,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long_fromb',
#       'n_reco': 4,
#       'n_particles': 4,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 95.83333333333334,
#       'avg_purity': 95.83333333333334,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long>5GeV',
#       'n_reco': 46,
#       'n_particles': 46,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 1,
#       'clone_percentage': 2.1739130434782608,
#       'purityT': 98.86524822695036,
#       'avg_purity': 98.86524822695037,
#       'avg_hiteff': 97.02127659574467,
#       'hit_eff_percentage': 97.02127659574467},
#      {'label': 'velo',
#       'n_reco': 220,
#       'n_particles': 233,
#       'recoeffT': 94.4206008583691,
#       'avg_recoeff': 94.4206008583691,
#       'n_clones': 12,
#       'clone_percentage': 5.454545454545454,
#       'purityT': 98.46132278187635,
#       'avg_purity': 98.46132278187635,
#       'avg_hiteff': 95.88542859270548,
#       'hit_eff_percentage': 95.88542859270548},
#      {'label': 'long_strange',
#       'n_reco': 3,
#       'n_particles': 3,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 100.0,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long',
#       'n_reco': 79,
#       'n_particles': 79,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 2,
#       'clone_percentage': 2.5316455696202533,
#       'purityT': 98.61204638982417,
#       'avg_purity': 98.61204638982417,
#       'avg_hiteff': 96.5999946555502,
#       'hit_eff_percentage': 96.5999946555502}],
#     '2': [{'label': 'long_fromb>5GeV',
#       'n_reco': 8,
#       'n_particles': 8,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.91666666666667,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long_fromb',
#       'n_reco': 9,
#       'n_particles': 9,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 98.14814814814815,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long>5GeV',
#       'n_reco': 66,
#       'n_particles': 66,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 2,
#       'clone_percentage': 3.0303030303030303,
#       'purityT': 98.95617070357557,
#       'avg_purity': 99.15966386554622,
#       'avg_hiteff': 93.52619602619603,
#       'hit_eff_percentage': 95.94191347867817},
#      {'label': 'velo',
#       'n_reco': 357,
#       'n_particles': 373,
#       'recoeffT': 95.71045576407506,
#       'avg_recoeff': 95.71045576407506,
#       'n_clones': 16,
#       'clone_percentage': 4.481792717086835,
#       'purityT': 98.73968803242786,
#       'avg_purity': 99.19770745177505,
#       'avg_hiteff': 96.77391166752871,
#       'hit_eff_percentage': 96.22128948694161},
#      {'label': 'long_strange',
#       'n_reco': 3,
#       'n_particles': 3,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 100.0,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long',
#       'n_reco': 114,
#       'n_particles': 114,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 3,
#       'clone_percentage': 2.6315789473684212,
#       'purityT': 98.74582933406464,
#       'avg_purity': 99.04684095860567,
#       'avg_hiteff': 95.48287360787361,
#       'hit_eff_percentage': 96.25626510241895}],
#     '3': [{'label': 'long_strange>5GeV',
#       'n_reco': 3,
#       'n_particles': 3,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 100.0,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long_fromb>5GeV',
#       'n_reco': 10,
#       'n_particles': 10,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.33333333333334,
#       'avg_purity': 95.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long_fromb',
#       'n_reco': 11,
#       'n_particles': 11,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.57575757575759,
#       'avg_purity': 95.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long>5GeV',
#       'n_reco': 130,
#       'n_particles': 131,
#       'recoeffT': 99.23664122137404,
#       'avg_recoeff': 99.23664122137404,
#       'n_clones': 4,
#       'clone_percentage': 3.076923076923077,
#       'purityT': 99.28017475646976,
#       'avg_purity': 99.61399711399712,
#       'avg_hiteff': 96.18686868686869,
#       'hit_eff_percentage': 96.06256305883171},
#      {'label': 'velo',
#       'n_reco': 656,
#       'n_particles': 692,
#       'recoeffT': 94.79768786127168,
#       'avg_recoeff': 94.79768786127167,
#       'n_clones': 27,
#       'clone_percentage': 4.115853658536586,
#       'purityT': 98.85895491487287,
#       'avg_purity': 99.00245990568573,
#       'avg_hiteff': 97.09714658101758,
#       'hit_eff_percentage': 96.61882345350612},
#      {'label': 'long_strange',
#       'n_reco': 8,
#       'n_particles': 8,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 98.61111111111111,
#       'avg_purity': 97.77777777777779,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long',
#       'n_reco': 212,
#       'n_particles': 213,
#       'recoeffT': 99.53051643192488,
#       'avg_recoeff': 99.53051643192488,
#       'n_clones': 7,
#       'clone_percentage': 3.30188679245283,
#       'purityT': 98.82282742476134,
#       'avg_purity': 98.91114876408994,
#       'avg_hiteff': 96.03832442067736,
#       'hit_eff_percentage': 96.15475848352561}],
#     '4': [{'label': 'long_strange>5GeV',
#       'n_reco': 5,
#       'n_particles': 5,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 100.0,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long_fromb>5GeV',
#       'n_reco': 13,
#       'n_particles': 13,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.3076923076923,
#       'avg_purity': 97.22222222222221,
#       'avg_hiteff': 97.22222222222221,
#       'hit_eff_percentage': 99.35897435897435},
#      {'label': 'long_fromb',
#       'n_reco': 14,
#       'n_particles': 14,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.5,
#       'avg_purity': 97.22222222222221,
#       'avg_hiteff': 97.22222222222221,
#       'hit_eff_percentage': 99.4047619047619},
#      {'label': 'long>5GeV',
#       'n_reco': 205,
#       'n_particles': 207,
#       'recoeffT': 99.03381642512078,
#       'avg_recoeff': 99.03381642512076,
#       'n_clones': 4,
#       'clone_percentage': 1.951219512195122,
#       'purityT': 98.75500105798446,
#       'avg_purity': 97.81669071669073,
#       'avg_hiteff': 99.14814814814815,
#       'hit_eff_percentage': 97.16983043538067},
#      {'label': 'velo',
#       'n_reco': 1038,
#       'n_particles': 1103,
#       'recoeffT': 94.10698096101541,
#       'avg_recoeff': 94.10698096101541,
#       'n_clones': 44,
#       'clone_percentage': 4.238921001926783,
#       'purityT': 98.47450730185662,
#       'avg_purity': 97.8164177788238,
#       'avg_hiteff': 95.40483604393378,
#       'hit_eff_percentage': 96.17115157141798},
#      {'label': 'long_strange',
#       'n_reco': 13,
#       'n_particles': 13,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 98.2905982905983,
#       'avg_purity': 97.77777777777779,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long',
#       'n_reco': 331,
#       'n_particles': 333,
#       'recoeffT': 99.3993993993994,
#       'avg_recoeff': 99.3993993993994,
#       'n_clones': 10,
#       'clone_percentage': 3.0211480362537766,
#       'purityT': 98.39767194260898,
#       'avg_purity': 97.63448300333543,
#       'avg_hiteff': 97.21932439145554,
#       'hit_eff_percentage': 96.53562957082018}],
#     '5': [{'label': 'long_strange>5GeV',
#       'n_reco': 5,
#       'n_particles': 5,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 100.0,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long_fromb>5GeV',
#       'n_reco': 17,
#       'n_particles': 17,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.94117647058822,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 99.50980392156862},
#      {'label': 'long_fromb',
#       'n_reco': 18,
#       'n_particles': 18,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 98.05555555555554,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 99.53703703703702},
#      {'label': 'long>5GeV',
#       'n_reco': 224,
#       'n_particles': 226,
#       'recoeffT': 99.11504424778761,
#       'avg_recoeff': 99.11504424778761,
#       'n_clones': 4,
#       'clone_percentage': 1.7857142857142858,
#       'purityT': 98.74910184701207,
#       'avg_purity': 98.68421052631578,
#       'avg_hiteff': 99.52153110047848,
#       'hit_eff_percentage': 97.3658054908055},
#      {'label': 'velo',
#       'n_reco': 1161,
#       'n_particles': 1243,
#       'recoeffT': 93.40305711987128,
#       'avg_recoeff': 93.40305711987128,
#       'n_clones': 47,
#       'clone_percentage': 4.04823428079242,
#       'purityT': 98.46701420889498,
#       'avg_purity': 98.4026687598116,
#       'avg_hiteff': 97.88325431182572,
#       'hit_eff_percentage': 96.34973182414264},
#      {'label': 'long_strange',
#       'n_reco': 13,
#       'n_particles': 13,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 98.2905982905983,
#       'avg_purity': 97.77777777777779,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long',
#       'n_reco': 361,
#       'n_particles': 363,
#       'recoeffT': 99.44903581267218,
#       'avg_recoeff': 99.44903581267218,
#       'n_clones': 11,
#       'clone_percentage': 3.0470914127423825,
#       'purityT': 98.44331673316492,
#       'avg_purity': 98.94540942928039,
#       'avg_hiteff': 95.83577712609971,
#       'hit_eff_percentage': 96.47730853376014}],
#     '6': [{'label': 'long_strange>5GeV',
#       'n_reco': 5,
#       'n_particles': 5,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 100.0,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long_fromb>5GeV',
#       'n_reco': 18,
#       'n_particles': 18,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 98.05555555555554,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 99.53703703703702},
#      {'label': 'long_fromb',
#       'n_reco': 21,
#       'n_particles': 21,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 98.33333333333333,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 99.6031746031746},
#      {'label': 'long>5GeV',
#       'n_reco': 276,
#       'n_particles': 280,
#       'recoeffT': 98.57142857142857,
#       'avg_recoeff': 98.57142857142858,
#       'n_clones': 7,
#       'clone_percentage': 2.536231884057971,
#       'purityT': 98.6868161977287,
#       'avg_purity': 98.42861386979035,
#       'avg_hiteff': 93.13636363636365,
#       'hit_eff_percentage': 96.54382915867015},
#      {'label': 'velo',
#       'n_reco': 1375,
#       'n_particles': 1470,
#       'recoeffT': 93.5374149659864,
#       'avg_recoeff': 93.5374149659864,
#       'n_clones': 57,
#       'clone_percentage': 4.1454545454545455,
#       'purityT': 98.47392446062605,
#       'avg_purity': 98.5111904610329,
#       'avg_hiteff': 95.47406462585035,
#       'hit_eff_percentage': 96.21275594954942},
#      {'label': 'long_strange',
#       'n_reco': 15,
#       'n_particles': 15,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 98.51851851851852,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long',
#       'n_reco': 433,
#       'n_particles': 437,
#       'recoeffT': 99.08466819221968,
#       'avg_recoeff': 99.08466819221968,
#       'n_clones': 14,
#       'clone_percentage': 3.233256351039261,
#       'purityT': 98.38828488848227,
#       'avg_purity': 98.11532693885636,
#       'avg_hiteff': 94.36349206349206,
#       'hit_eff_percentage': 96.12264134076214}],
#     '7': [{'label': 'long_strange>5GeV',
#       'n_reco': 9,
#       'n_particles': 9,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 96.19047619047619,
#       'avg_purity': 91.42857142857143,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long_fromb>5GeV',
#       'n_reco': 23,
#       'n_particles': 23,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.47491638795985,
#       'avg_purity': 95.38461538461537,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 99.63768115942028},
#      {'label': 'long_fromb',
#       'n_reco': 26,
#       'n_particles': 26,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.76627218934911,
#       'avg_purity': 95.38461538461537,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 99.67948717948717},
#      {'label': 'long>5GeV',
#       'n_reco': 337,
#       'n_particles': 342,
#       'recoeffT': 98.53801169590643,
#       'avg_recoeff': 98.53801169590643,
#       'n_clones': 7,
#       'clone_percentage': 2.077151335311573,
#       'purityT': 98.45383175496035,
#       'avg_purity': 97.37293671719898,
#       'avg_hiteff': 99.39384386105698,
#       'hit_eff_percentage': 97.04920967275619},
#      {'label': 'velo',
#       'n_reco': 1654,
#       'n_particles': 1765,
#       'recoeffT': 93.71104815864022,
#       'avg_recoeff': 93.71104815864022,
#       'n_clones': 64,
#       'clone_percentage': 3.8694074969770256,
#       'purityT': 98.49088163724757,
#       'avg_purity': 98.57578610200989,
#       'avg_hiteff': 96.11407628890147,
#       'hit_eff_percentage': 96.19632848566972},
#      {'label': 'long_strange',
#       'n_reco': 21,
#       'n_particles': 21,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.30914588057446,
#       'avg_purity': 94.28571428571428,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long',
#       'n_reco': 534,
#       'n_particles': 539,
#       'recoeffT': 99.07235621521336,
#       'avg_recoeff': 99.07235621521335,
#       'n_clones': 15,
#       'clone_percentage': 2.808988764044944,
#       'purityT': 98.32614737548843,
#       'avg_purity': 98.05383886266239,
#       'avg_hiteff': 98.13234151469445,
#       'hit_eff_percentage': 96.49602825832334}],
#     '8': [{'label': 'long_strange>5GeV',
#       'n_reco': 10,
#       'n_particles': 10,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 96.57142857142857,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long_fromb>5GeV',
#       'n_reco': 28,
#       'n_particles': 28,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 96.43772893772893,
#       'avg_purity': 91.66666666666667,
#       'avg_hiteff': 90.0,
#       'hit_eff_percentage': 97.91666666666666},
#      {'label': 'long_fromb',
#       'n_reco': 33,
#       'n_particles': 33,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 96.54456654456655,
#       'avg_purity': 92.00680272108845,
#       'avg_hiteff': 92.85714285714286,
#       'hit_eff_percentage': 98.23232323232322},
#      {'label': 'long>5GeV',
#       'n_reco': 400,
#       'n_particles': 405,
#       'recoeffT': 98.76543209876543,
#       'avg_recoeff': 98.76543209876543,
#       'n_clones': 8,
#       'clone_percentage': 2.0,
#       'purityT': 98.38287585476166,
#       'avg_purity': 98.00148789119378,
#       'avg_hiteff': 98.18080357142858,
#       'hit_eff_percentage': 97.22671459803813},
#      {'label': 'velo',
#       'n_reco': 1987,
#       'n_particles': 2120,
#       'recoeffT': 93.72641509433963,
#       'avg_recoeff': 93.72641509433961,
#       'n_clones': 74,
#       'clone_percentage': 3.724207347760443,
#       'purityT': 98.48642462283794,
#       'avg_purity': 98.46410056815648,
#       'avg_hiteff': 96.65776562278022,
#       'hit_eff_percentage': 96.27312273022523},
#      {'label': 'long_strange',
#       'n_reco': 27,
#       'n_particles': 27,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.64256319811876,
#       'avg_purity': 98.80952380952381,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long',
#       'n_reco': 635,
#       'n_particles': 640,
#       'recoeffT': 99.21875,
#       'avg_recoeff': 99.21875,
#       'n_clones': 17,
#       'clone_percentage': 2.677165354330709,
#       'purityT': 98.36153613918862,
#       'avg_purity': 98.55016168551292,
#       'avg_hiteff': 97.79087686854677,
#       'hit_eff_percentage': 96.70058256331262}],
#     '9': [{'label': 'long_strange>5GeV',
#       'n_reco': 11,
#       'n_particles': 11,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 96.88311688311687,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long_fromb>5GeV',
#       'n_reco': 33,
#       'n_particles': 33,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 96.76101676101676,
#       'avg_purity': 98.57142857142858,
#       'avg_hiteff': 98.57142857142858,
#       'hit_eff_percentage': 98.01587301587301},
#      {'label': 'long_fromb',
#       'n_reco': 40,
#       'n_particles': 40,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 96.34569597069597,
#       'avg_purity': 95.40816326530613,
#       'avg_hiteff': 98.9795918367347,
#       'hit_eff_percentage': 98.36309523809524},
#      {'label': 'long>5GeV',
#       'n_reco': 437,
#       'n_particles': 442,
#       'recoeffT': 98.86877828054298,
#       'avg_recoeff': 98.86877828054298,
#       'n_clones': 12,
#       'clone_percentage': 2.745995423340961,
#       'purityT': 98.36562523317403,
#       'avg_purity': 98.19396051103368,
#       'avg_hiteff': 91.28919860627175,
#       'hit_eff_percentage': 96.68453607763186},
#      {'label': 'velo',
#       'n_reco': 2148,
#       'n_particles': 2294,
#       'recoeffT': 93.63557105492589,
#       'avg_recoeff': 93.63557105492589,
#       'n_clones': 81,
#       'clone_percentage': 3.7709497206703912,
#       'purityT': 98.50514618879524,
#       'avg_purity': 98.73481968544992,
#       'avg_hiteff': 95.87931579003008,
#       'hit_eff_percentage': 96.24344145344068},
#      {'label': 'long_strange',
#       'n_reco': 29,
#       'n_particles': 29,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.80514504652437,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long',
#       'n_reco': 687,
#       'n_particles': 693,
#       'recoeffT': 99.13419913419914,
#       'avg_recoeff': 99.13419913419914,
#       'n_clones': 21,
#       'clone_percentage': 3.056768558951965,
#       'purityT': 98.30969234321678,
#       'avg_purity': 97.70608243297318,
#       'avg_hiteff': 93.62244897959184,
#       'hit_eff_percentage': 96.45711437024995}],
#     '10': [{'label': 'long_strange>5GeV',
#       'n_reco': 11,
#       'n_particles': 11,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 96.88311688311687,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long_fromb>5GeV',
#       'n_reco': 37,
#       'n_particles': 37,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.11117711117711,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 98.23037323037323},
#      {'label': 'long_fromb',
#       'n_reco': 48,
#       'n_particles': 48,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 96.95474664224663,
#       'avg_purity': 100.0,
#       'avg_hiteff': 97.91666666666667,
#       'hit_eff_percentage': 98.28869047619048},
#      {'label': 'long>5GeV',
#       'n_reco': 466,
#       'n_particles': 471,
#       'recoeffT': 98.93842887473461,
#       'avg_recoeff': 98.93842887473461,
#       'n_clones': 13,
#       'clone_percentage': 2.7896995708154506,
#       'purityT': 98.34711671043489,
#       'avg_purity': 98.07010582010582,
#       'avg_hiteff': 93.51515151515152,
#       'hit_eff_percentage': 96.48603600064979},
#      {'label': 'velo',
#       'n_reco': 2359,
#       'n_particles': 2516,
#       'recoeffT': 93.75993640699524,
#       'avg_recoeff': 93.75993640699522,
#       'n_clones': 88,
#       'clone_percentage': 3.7303942348452734,
#       'purityT': 98.5115377031412,
#       'avg_purity': 98.5768894713849,
#       'avg_hiteff': 95.53688920661399,
#       'hit_eff_percentage': 96.1804956464083},
#      {'label': 'long_strange',
#       'n_reco': 30,
#       'n_particles': 30,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.87830687830689,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long',
#       'n_reco': 732,
#       'n_particles': 738,
#       'recoeffT': 99.1869918699187,
#       'avg_recoeff': 99.1869918699187,
#       'n_clones': 23,
#       'clone_percentage': 3.1420765027322406,
#       'purityT': 98.3382322564247,
#       'avg_purity': 98.76815265113137,
#       'avg_hiteff': 93.37846550612508,
#       'hit_eff_percentage': 96.26546338135742}],
#     '11': [{'label': 'long_strange>5GeV',
#       'n_reco': 12,
#       'n_particles': 13,
#       'recoeffT': 92.3076923076923,
#       'avg_recoeff': 92.3076923076923,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.14285714285712,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long_fromb>5GeV',
#       'n_reco': 41,
#       'n_particles': 41,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.39301349057448,
#       'avg_purity': 100.0,
#       'avg_hiteff': 94.44444444444444,
#       'hit_eff_percentage': 97.86101432442896},
#      {'label': 'long_fromb',
#       'n_reco': 53,
#       'n_particles': 53,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.07050810824396,
#       'avg_purity': 98.18181818181819,
#       'avg_hiteff': 95.55555555555554,
#       'hit_eff_percentage': 98.03084755914945},
#      {'label': 'long>5GeV',
#       'n_reco': 530,
#       'n_particles': 537,
#       'recoeffT': 98.69646182495345,
#       'avg_recoeff': 98.69646182495345,
#       'n_clones': 14,
#       'clone_percentage': 2.641509433962264,
#       'purityT': 98.37938094561149,
#       'avg_purity': 98.61714354022045,
#       'avg_hiteff': 97.89142481450173,
#       'hit_eff_percentage': 96.65395929642253},
#      {'label': 'velo',
#       'n_reco': 2755,
#       'n_particles': 2933,
#       'recoeffT': 93.93112853733379,
#       'avg_recoeff': 93.93112853733379,
#       'n_clones': 98,
#       'clone_percentage': 3.557168784029038,
#       'purityT': 98.47443295344398,
#       'avg_purity': 98.25079915416049,
#       'avg_hiteff': 96.61739122946021,
#       'hit_eff_percentage': 96.24266865962915},
#      {'label': 'long_strange',
#       'n_reco': 36,
#       'n_particles': 37,
#       'recoeffT': 97.29729729729729,
#       'avg_recoeff': 97.2972972972973,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 98.23192239858908,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long',
#       'n_reco': 846,
#       'n_particles': 854,
#       'recoeffT': 99.06323185011709,
#       'avg_recoeff': 99.06323185011709,
#       'n_clones': 24,
#       'clone_percentage': 2.8368794326241136,
#       'purityT': 98.39536153126417,
#       'avg_purity': 98.77042763999285,
#       'avg_hiteff': 97.05931025496241,
#       'hit_eff_percentage': 96.37039716350061}],
#     '12': [{'label': 'long_strange>5GeV',
#       'n_reco': 13,
#       'n_particles': 14,
#       'recoeffT': 92.85714285714286,
#       'avg_recoeff': 92.85714285714286,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.36263736263734,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long_fromb>5GeV',
#       'n_reco': 43,
#       'n_particles': 43,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.51426867705938,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 97.96050203026948},
#      {'label': 'long_fromb',
#       'n_reco': 56,
#       'n_particles': 56,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.00423088815946,
#       'avg_purity': 95.83333333333334,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 98.13633786848072},
#      {'label': 'long>5GeV',
#       'n_reco': 552,
#       'n_particles': 559,
#       'recoeffT': 98.74776386404294,
#       'avg_recoeff': 98.74776386404294,
#       'n_clones': 14,
#       'clone_percentage': 2.536231884057971,
#       'purityT': 98.42470536115307,
#       'avg_purity': 99.54545454545453,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 96.78401741564285},
#      {'label': 'velo',
#       'n_reco': 2869,
#       'n_particles': 3054,
#       'recoeffT': 93.94237066142763,
#       'avg_recoeff': 93.94237066142763,
#       'n_clones': 99,
#       'clone_percentage': 3.4506796793307775,
#       'purityT': 98.49784529488656,
#       'avg_purity': 99.07867494824016,
#       'avg_hiteff': 98.57660455486543,
#       'hit_eff_percentage': 96.33310081190415},
#      {'label': 'long_strange',
#       'n_reco': 43,
#       'n_particles': 44,
#       'recoeffT': 97.72727272727273,
#       'avg_recoeff': 97.72727272727273,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 98.51974898486527,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long',
#       'n_reco': 885,
#       'n_particles': 894,
#       'recoeffT': 98.99328859060402,
#       'avg_recoeff': 98.99328859060402,
#       'n_clones': 24,
#       'clone_percentage': 2.711864406779661,
#       'purityT': 98.4394549309129,
#       'avg_purity': 99.42307692307692,
#       'avg_hiteff': 99.82905982905984,
#       'hit_eff_percentage': 96.51878863099986}],
#     '13': [{'label': 'long_strange>5GeV',
#       'n_reco': 13,
#       'n_particles': 14,
#       'recoeffT': 92.85714285714286,
#       'avg_recoeff': 92.85714285714286,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.36263736263734,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long_fromb>5GeV',
#       'n_reco': 47,
#       'n_particles': 47,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 1,
#       'clone_percentage': 2.127659574468085,
#       'purityT': 95.50047175047173,
#       'avg_purity': 97.72727272727273,
#       'avg_hiteff': 97.72727272727273,
#       'hit_eff_percentage': 97.94065272788677},
#      {'label': 'long_fromb',
#       'n_reco': 62,
#       'n_particles': 62,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 1,
#       'clone_percentage': 1.6129032258064515,
#       'purityT': 95.37873502159216,
#       'avg_purity': 96.1038961038961,
#       'avg_hiteff': 98.48484848484848,
#       'hit_eff_percentage': 98.17006470232276},
#      {'label': 'long>5GeV',
#       'n_reco': 602,
#       'n_particles': 610,
#       'recoeffT': 98.68852459016394,
#       'avg_recoeff': 98.68852459016394,
#       'n_clones': 16,
#       'clone_percentage': 2.6578073089700998,
#       'purityT': 98.28398939406935,
#       'avg_purity': 98.64945512004334,
#       'avg_hiteff': 97.41745182921653,
#       'hit_eff_percentage': 96.83637585177293},
#      {'label': 'velo',
#       'n_reco': 3206,
#       'n_particles': 3412,
#       'recoeffT': 93.96248534583822,
#       'avg_recoeff': 93.96248534583822,
#       'n_clones': 113,
#       'clone_percentage': 3.5246412975670616,
#       'purityT': 98.45794881660599,
#       'avg_purity': 98.40093510597711,
#       'avg_hiteff': 96.19736017950308,
#       'hit_eff_percentage': 96.31878217979433},
#      {'label': 'long_strange',
#       'n_reco': 44,
#       'n_particles': 45,
#       'recoeffT': 97.77777777777777,
#       'avg_recoeff': 97.77777777777777,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 98.55339105339107,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long',
#       'n_reco': 968,
#       'n_particles': 978,
#       'recoeffT': 98.97750511247443,
#       'avg_recoeff': 98.97750511247445,
#       'n_clones': 26,
#       'clone_percentage': 2.6859504132231407,
#       'purityT': 98.37426088003079,
#       'avg_purity': 98.8398902684617,
#       'avg_hiteff': 98.0070904624476,
#       'hit_eff_percentage': 96.64468727535193}],
#     '14': [{'label': 'long_strange>5GeV',
#       'n_reco': 14,
#       'n_particles': 15,
#       'recoeffT': 93.33333333333333,
#       'avg_recoeff': 93.33333333333333,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.55102040816325,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long_fromb>5GeV',
#       'n_reco': 49,
#       'n_particles': 49,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 1,
#       'clone_percentage': 2.0408163265306123,
#       'purityT': 95.68045288045286,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 98.02470771858528},
#      {'label': 'long_fromb',
#       'n_reco': 64,
#       'n_particles': 64,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 1,
#       'clone_percentage': 1.5625,
#       'purityT': 95.52092779015855,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 98.22725018037518},
#      {'label': 'long>5GeV',
#       'n_reco': 651,
#       'n_particles': 659,
#       'recoeffT': 98.78603945371775,
#       'avg_recoeff': 98.78603945371776,
#       'n_clones': 17,
#       'clone_percentage': 2.61136712749616,
#       'purityT': 98.2939738473215,
#       'avg_purity': 98.41738168951791,
#       'avg_hiteff': 96.53846986346984,
#       'hit_eff_percentage': 96.8140440685418},
#      {'label': 'velo',
#       'n_reco': 3436,
#       'n_particles': 3651,
#       'recoeffT': 94.11120241029855,
#       'avg_recoeff': 94.11120241029855,
#       'n_clones': 117,
#       'clone_percentage': 3.4051222351571595,
#       'purityT': 98.47570826996382,
#       'avg_purity': 98.72760410626567,
#       'avg_hiteff': 96.83779124484253,
#       'hit_eff_percentage': 96.35297365536337},
#      {'label': 'long_strange',
#       'n_reco': 45,
#       'n_particles': 47,
#       'recoeffT': 95.74468085106383,
#       'avg_recoeff': 95.74468085106383,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 98.58553791887127,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 100.0},
#      {'label': 'long',
#       'n_reco': 1041,
#       'n_particles': 1052,
#       'recoeffT': 98.95437262357414,
#       'avg_recoeff': 98.95437262357414,
#       'n_clones': 28,
#       'clone_percentage': 2.689721421709894,
#       'purityT': 98.3999062524246,
#       'avg_purity': 98.73979292121709,
#       'avg_hiteff': 95.33048988048988,
#       'hit_eff_percentage': 96.55239813245431}],
#     '15': [{'label': 'long_strange>5GeV',
#       'n_reco': 16,
#       'n_particles': 17,
#       'recoeffT': 94.11764705882354,
#       'avg_recoeff': 94.11764705882352,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.85714285714285,
#       'avg_purity': 100.0,
#       'avg_hiteff': 96.875,
#       'hit_eff_percentage': 99.609375},
#      {'label': 'long_fromb>5GeV',
#       'n_reco': 51,
#       'n_particles': 51,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 1,
#       'clone_percentage': 1.9607843137254901,
#       'purityT': 95.60620469274315,
#       'avg_purity': 93.75,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 98.1021701609937},
#      {'label': 'long_fromb',
#       'n_reco': 67,
#       'n_particles': 67,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 1,
#       'clone_percentage': 1.492537313432836,
#       'purityT': 95.53471038765156,
#       'avg_purity': 95.83333333333334,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 98.30662703797033},
#      {'label': 'long>5GeV',
#       'n_reco': 729,
#       'n_particles': 740,
#       'recoeffT': 98.51351351351352,
#       'avg_recoeff': 98.51351351351352,
#       'n_clones': 20,
#       'clone_percentage': 2.7434842249657065,
#       'purityT': 98.20979905279094,
#       'avg_purity': 97.51561679666253,
#       'avg_hiteff': 97.29551141588179,
#       'hit_eff_percentage': 96.86618157540616},
#      {'label': 'velo',
#       'n_reco': 3827,
#       'n_particles': 4068,
#       'recoeffT': 94.07571288102261,
#       'avg_recoeff': 94.07571288102261,
#       'n_clones': 129,
#       'clone_percentage': 3.3707865168539324,
#       'purityT': 98.48520860673405,
#       'avg_purity': 98.56896715895401,
#       'avg_hiteff': 96.61893283171197,
#       'hit_eff_percentage': 96.38007392036174},
#      {'label': 'long_strange',
#       'n_reco': 49,
#       'n_particles': 51,
#       'recoeffT': 96.07843137254902,
#       'avg_recoeff': 96.07843137254902,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 98.7010042112083,
#       'avg_purity': 100.0,
#       'avg_hiteff': 94.86607142857143,
#       'hit_eff_percentage': 99.58090379008746},
#      {'label': 'long',
#       'n_reco': 1167,
#       'n_particles': 1182,
#       'recoeffT': 98.73096446700508,
#       'avg_recoeff': 98.73096446700508,
#       'n_clones': 33,
#       'clone_percentage': 2.827763496143959,
#       'purityT': 98.35702464961366,
#       'avg_purity': 98.00709767705726,
#       'avg_hiteff': 96.7627908563023,
#       'hit_eff_percentage': 96.57538516066457}],
#     '16': [{'label': 'long_strange>5GeV',
#       'n_reco': 17,
#       'n_particles': 18,
#       'recoeffT': 94.44444444444444,
#       'avg_recoeff': 94.44444444444444,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.98319327731093,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 99.63235294117646},
#      {'label': 'long_fromb>5GeV',
#       'n_reco': 52,
#       'n_particles': 52,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 1,
#       'clone_percentage': 1.9230769230769231,
#       'purityT': 95.68910649099327,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 98.13866688866689},
#      {'label': 'long_fromb',
#       'n_reco': 68,
#       'n_particles': 68,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 1,
#       'clone_percentage': 1.4705882352941178,
#       'purityT': 95.5994247298595,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 98.3315295815296},
#      {'label': 'long>5GeV',
#       'n_reco': 798,
#       'n_particles': 809,
#       'recoeffT': 98.64029666254635,
#       'avg_recoeff': 98.64029666254636,
#       'n_clones': 23,
#       'clone_percentage': 2.882205513784461,
#       'purityT': 98.2445127885635,
#       'avg_purity': 98.60563206764188,
#       'avg_hiteff': 94.93951978939725,
#       'hit_eff_percentage': 96.69701127224441},
#      {'label': 'velo',
#       'n_reco': 4145,
#       'n_particles': 4411,
#       'recoeffT': 93.96962140104284,
#       'avg_recoeff': 93.96962140104284,
#       'n_clones': 138,
#       'clone_percentage': 3.3293124246079615,
#       'purityT': 98.47626246487863,
#       'avg_purity': 98.36803329919044,
#       'avg_hiteff': 97.19076315541506,
#       'hit_eff_percentage': 96.44198316367385},
#      {'label': 'long_strange',
#       'n_reco': 52,
#       'n_particles': 54,
#       'recoeffT': 96.29629629629629,
#       'avg_recoeff': 96.29629629629629,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 98.77594627594628,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 99.60508241758241},
#      {'label': 'long',
#       'n_reco': 1270,
#       'n_particles': 1287,
#       'recoeffT': 98.67909867909867,
#       'avg_recoeff': 98.67909867909867,
#       'n_clones': 36,
#       'clone_percentage': 2.8346456692913384,
#       'purityT': 98.33983163795202,
#       'avg_purity': 98.14519377008425,
#       'avg_hiteff': 96.0909945739302,
#       'hit_eff_percentage': 96.53604002488385}],
#     '17': [{'label': 'long_strange>5GeV',
#       'n_reco': 22,
#       'n_particles': 23,
#       'recoeffT': 95.65217391304348,
#       'avg_recoeff': 95.65217391304348,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.3051948051948,
#       'avg_purity': 95.0,
#       'avg_hiteff': 96.0,
#       'hit_eff_percentage': 98.80681818181819},
#      {'label': 'long_fromb>5GeV',
#       'n_reco': 53,
#       'n_particles': 53,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 1,
#       'clone_percentage': 1.8867924528301887,
#       'purityT': 95.76893785227118,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 98.17378638133356},
#      {'label': 'long_fromb',
#       'n_reco': 71,
#       'n_particles': 71,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 1,
#       'clone_percentage': 1.408450704225352,
#       'purityT': 95.41075822325823,
#       'avg_purity': 91.07142857142857,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 98.4020283316058},
#      {'label': 'long>5GeV',
#       'n_reco': 849,
#       'n_particles': 860,
#       'recoeffT': 98.72093023255815,
#       'avg_recoeff': 98.72093023255813,
#       'n_clones': 25,
#       'clone_percentage': 2.944640753828033,
#       'purityT': 98.23203270790873,
#       'avg_purity': 98.03870919436959,
#       'avg_hiteff': 94.75996487788939,
#       'hit_eff_percentage': 96.57941280844048},
#      {'label': 'velo',
#       'n_reco': 4389,
#       'n_particles': 4675,
#       'recoeffT': 93.88235294117646,
#       'avg_recoeff': 93.88235294117648,
#       'n_clones': 149,
#       'clone_percentage': 3.394850763271816,
#       'purityT': 98.45023307150569,
#       'avg_purity': 98.01304133889275,
#       'avg_hiteff': 96.57820773997247,
#       'hit_eff_percentage': 96.44963960338205},
#      {'label': 'long_strange',
#       'n_reco': 60,
#       'n_particles': 62,
#       'recoeffT': 96.7741935483871,
#       'avg_recoeff': 96.7741935483871,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 98.52248677248677,
#       'avg_purity': 96.875,
#       'avg_hiteff': 97.5,
#       'hit_eff_percentage': 99.32440476190476},
#      {'label': 'long',
#       'n_reco': 1356,
#       'n_particles': 1374,
#       'recoeffT': 98.68995633187772,
#       'avg_recoeff': 98.68995633187772,
#       'n_clones': 41,
#       'clone_percentage': 3.023598820058997,
#       'purityT': 98.31401269561272,
#       'avg_purity': 97.94346831434747,
#       'avg_hiteff': 94.85496646210933,
#       'hit_eff_percentage': 96.42645714937346}],
#     '18': [{'label': 'long_strange>5GeV',
#       'n_reco': 25,
#       'n_particles': 26,
#       'recoeffT': 96.15384615384616,
#       'avg_recoeff': 96.15384615384616,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.62857142857143,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 98.95},
#      {'label': 'long_fromb>5GeV',
#       'n_reco': 60,
#       'n_particles': 60,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 1,
#       'clone_percentage': 1.6666666666666667,
#       'purityT': 96.12836616934977,
#       'avg_purity': 98.9010989010989,
#       'avg_hiteff': 98.8095238095238,
#       'hit_eff_percentage': 98.24795574795574},
#      {'label': 'long_fromb',
#       'n_reco': 78,
#       'n_particles': 78,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 1,
#       'clone_percentage': 1.2820512820512822,
#       'purityT': 95.72002891623144,
#       'avg_purity': 98.9010989010989,
#       'avg_hiteff': 98.8095238095238,
#       'hit_eff_percentage': 98.43859843859845},
#      {'label': 'long>5GeV',
#       'n_reco': 880,
#       'n_particles': 891,
#       'recoeffT': 98.76543209876543,
#       'avg_recoeff': 98.76543209876543,
#       'n_clones': 26,
#       'clone_percentage': 2.9545454545454546,
#       'purityT': 98.2617287605319,
#       'avg_purity': 99.0728021978022,
#       'avg_hiteff': 95.28044871794872,
#       'hit_eff_percentage': 96.53348258645624},
#      {'label': 'velo',
#       'n_reco': 4522,
#       'n_particles': 4809,
#       'recoeffT': 94.0320232896652,
#       'avg_recoeff': 94.03202328966522,
#       'n_clones': 153,
#       'clone_percentage': 3.3834586466165413,
#       'purityT': 98.47282348728021,
#       'avg_purity': 99.2211103981177,
#       'avg_hiteff': 95.96336419651146,
#       'hit_eff_percentage': 96.43538634477245},
#      {'label': 'long_strange',
#       'n_reco': 66,
#       'n_particles': 68,
#       'recoeffT': 97.05882352941177,
#       'avg_recoeff': 97.05882352941177,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 98.54858104858104,
#       'avg_purity': 98.80952380952381,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 99.38582251082249},
#      {'label': 'long',
#       'n_reco': 1397,
#       'n_particles': 1415,
#       'recoeffT': 98.7279151943463,
#       'avg_recoeff': 98.7279151943463,
#       'n_clones': 42,
#       'clone_percentage': 3.006442376521117,
#       'purityT': 98.3376390194286,
#       'avg_purity': 99.12349555206697,
#       'avg_hiteff': 96.4041514041514,
#       'hit_eff_percentage': 96.42580566029187}],
#     '19': [{'label': 'long_strange>5GeV',
#       'n_reco': 25,
#       'n_particles': 26,
#       'recoeffT': 96.15384615384616,
#       'avg_recoeff': 96.15384615384616,
#       'n_clones': 0,
#       'clone_percentage': 0.0,
#       'purityT': 97.62857142857143,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 98.95},
#      {'label': 'long_fromb>5GeV',
#       'n_reco': 63,
#       'n_particles': 63,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 2,
#       'clone_percentage': 3.1746031746031744,
#       'purityT': 96.36662055892826,
#       'avg_purity': 100.0,
#       'avg_hiteff': 75.0,
#       'hit_eff_percentage': 96.79495851370851},
#      {'label': 'long_fromb',
#       'n_reco': 83,
#       'n_particles': 83,
#       'recoeffT': 100.0,
#       'avg_recoeff': 100.0,
#       'n_clones': 2,
#       'clone_percentage': 2.4096385542168677,
#       'purityT': 96.02214452214452,
#       'avg_purity': 100.0,
#       'avg_hiteff': 83.33333333333334,
#       'hit_eff_percentage': 97.35965093107951},
#      {'label': 'long>5GeV',
#       'n_reco': 942,
#       'n_particles': 954,
#       'recoeffT': 98.74213836477988,
#       'avg_recoeff': 98.74213836477988,
#       'n_clones': 29,
#       'clone_percentage': 3.0785562632696393,
#       'purityT': 98.29499472340787,
#       'avg_purity': 98.75867106749459,
#       'avg_hiteff': 97.38700188700187,
#       'hit_eff_percentage': 96.59067717876084},
#      {'label': 'velo',
#       'n_reco': 4812,
#       'n_particles': 5123,
#       'recoeffT': 93.92933827835253,
#       'avg_recoeff': 93.92933827835253,
#       'n_clones': 163,
#       'clone_percentage': 3.3873649210307564,
#       'purityT': 98.4480301367555,
#       'avg_purity': 98.06166709107885,
#       'avg_hiteff': 96.71760091760095,
#       'hit_eff_percentage': 96.45240773034715},
#      {'label': 'long_strange',
#       'n_reco': 66,
#       'n_particles': 68,
#       'recoeffT': 97.05882352941177,
# ...
#       'n_reco': 513,
#       'n_particles': 532,
#       'recoeffT': 96.42857142857143,
#       'avg_recoeff': 96.42857142857143,
#       'n_clones': 11,
#       'clone_percentage': 2.1442495126705654,
#       'purityT': 97.09079431765872,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 96.54517460444805},
#      {'label': 'long',
#       'n_reco': 11519,
#       'n_particles': 11838,
#       'recoeffT': 97.30528805541476,
#       'avg_recoeff': 97.30528805541476,
#       'n_clones': 360,
#       'clone_percentage': 3.1252712909106695,
#       'purityT': 97.58211127460876,
#       'avg_purity': 96.45116368493649,
#       'avg_hiteff': 93.8013423358251,
#       'hit_eff_percentage': 96.4529609445852},
#      {'label': 'long>5GeV',
#       'n_reco': 7258,
#       'n_particles': 7441,
#       'recoeffT': 97.54065313801908,
#       'avg_recoeff': 97.54065313801908,
#       'n_clones': 220,
#       'clone_percentage': 3.031138054560485,
#       'purityT': 97.52101455797981,
#       'avg_purity': 96.17667694249268,
#       'avg_hiteff': 90.65150782131911,
#       'hit_eff_percentage': 96.71050107871426},
#      {'label': 'long_fromb',
#       'n_reco': 646,
#       'n_particles': 669,
#       'recoeffT': 96.56203288490283,
#       'avg_recoeff': 96.56203288490283,
#       'n_clones': 14,
#       'clone_percentage': 2.1671826625387,
#       'purityT': 97.24011761671835,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 96.78490635689603},
#      {'label': 'long_strange',
#       'n_reco': 532,
#       'n_particles': 561,
#       'recoeffT': 94.83065953654189,
#       'avg_recoeff': 94.8306595365419,
#       'n_clones': 10,
#       'clone_percentage': 1.8796992481203008,
#       'purityT': 96.86571175268294,
#       'avg_purity': 95.27777777777779,
#       'avg_hiteff': 89.99999999999999,
#       'hit_eff_percentage': 97.97390007491481},
#      {'label': 'long_strange>5GeV',
#       'n_reco': 246,
#       'n_particles': 258,
#       'recoeffT': 95.34883720930233,
#       'avg_recoeff': 95.34883720930233,
#       'n_clones': 7,
#       'clone_percentage': 2.845528455284553,
#       'purityT': 97.10196669474804,
#       'avg_purity': 91.90476190476191,
#       'avg_hiteff': 82.85714285714285,
#       'hit_eff_percentage': 97.50042612196764},
#      {'label': 'velo',
#       'n_reco': 37460,
#       'n_particles': 40896,
#       'recoeffT': 91.59820031298905,
#       'avg_recoeff': 91.59820031298904,
#       'n_clones': 1384,
#       'clone_percentage': 3.6946075814201813,
#       'purityT': 97.96327155644158,
#       'avg_purity': 97.49346609891397,
#       'avg_hiteff': 95.83198997971726,
#       'hit_eff_percentage': 96.34912996556807}],
#     '145': [{'label': 'long_fromb>5GeV',
#       'n_reco': 516,
#       'n_particles': 535,
#       'recoeffT': 96.44859813084112,
#       'avg_recoeff': 96.44859813084112,
#       'n_clones': 11,
#       'clone_percentage': 2.131782945736434,
#       'purityT': 97.09010495894168,
#       'avg_purity': 96.96969696969697,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 96.5648789317991},
#      {'label': 'long',
#       'n_reco': 11601,
#       'n_particles': 11921,
#       'recoeffT': 97.31566143779884,
#       'avg_recoeff': 97.31566143779884,
#       'n_clones': 362,
#       'clone_percentage': 3.120420653391949,
#       'purityT': 97.58681954060854,
#       'avg_purity': 98.25264682407538,
#       'avg_hiteff': 98.77790859933717,
#       'hit_eff_percentage': 96.46928727822501},
#      {'label': 'long>5GeV',
#       'n_reco': 7315,
#       'n_particles': 7499,
#       'recoeffT': 97.54633951193493,
#       'avg_recoeff': 97.54633951193492,
#       'n_clones': 222,
#       'clone_percentage': 3.03485987696514,
#       'purityT': 97.5239566811049,
#       'avg_purity': 97.89685832058711,
#       'avg_hiteff': 98.80331532873905,
#       'hit_eff_percentage': 96.72688590365475},
#      {'label': 'long_fromb',
#       'n_reco': 649,
#       'n_particles': 672,
#       'recoeffT': 96.57738095238095,
#       'avg_recoeff': 96.57738095238095,
#       'n_clones': 14,
#       'clone_percentage': 2.157164869029276,
#       'purityT': 97.23889399388115,
#       'avg_purity': 96.96969696969697,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 96.79947626766538},
#      {'label': 'long_strange',
#       'n_reco': 533,
#       'n_particles': 562,
#       'recoeffT': 94.83985765124555,
#       'avg_recoeff': 94.83985765124555,
#       'n_clones': 10,
#       'clone_percentage': 1.876172607879925,
#       'purityT': 96.8714839225675,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 97.97763138232749},
#      {'label': 'long_strange>5GeV',
#       'n_reco': 246,
#       'n_particles': 258,
#       'recoeffT': 95.34883720930233,
#       'avg_recoeff': 95.34883720930233,
#       'n_clones': 7,
#       'clone_percentage': 2.845528455284553,
#       'purityT': 97.10196669474804,
#       'avg_purity': 91.90476190476191,
#       'avg_hiteff': 82.85714285714285,
#       'hit_eff_percentage': 97.50042612196764},
#      {'label': 'velo',
#       'n_reco': 37697,
#       'n_particles': 41147,
#       'recoeffT': 91.61542761319173,
#       'avg_recoeff': 91.61542761319173,
#       'n_clones': 1393,
#       'clone_percentage': 3.6952542642650608,
#       'purityT': 97.96136553940588,
#       'avg_purity': 97.66040080064472,
#       'avg_hiteff': 97.11022886327767,
#       'hit_eff_percentage': 96.35392005764054}],
#     '146': [{'label': 'long_fromb>5GeV',
#       'n_reco': 522,
#       'n_particles': 541,
#       'recoeffT': 96.48798521256931,
#       'avg_recoeff': 96.48798521256931,
#       'n_clones': 11,
#       'clone_percentage': 2.10727969348659,
#       'purityT': 97.12286175114873,
#       'avg_purity': 100.0,
#       'avg_hiteff': 97.2027972027972,
#       'hit_eff_percentage': 96.57207349876523},
#      {'label': 'long',
#       'n_reco': 11739,
#       'n_particles': 12061,
#       'recoeffT': 97.33023795705165,
#       'avg_recoeff': 97.33023795705165,
#       'n_clones': 366,
#       'clone_percentage': 3.1178124201380015,
#       'purityT': 97.56825663168293,
#       'avg_purity': 96.00439691705554,
#       'avg_hiteff': 96.8940625102597,
#       'hit_eff_percentage': 96.47427059638007},
#      {'label': 'long>5GeV',
#       'n_reco': 7404,
#       'n_particles': 7589,
#       'recoeffT': 97.56226116747925,
#       'avg_recoeff': 97.56226116747925,
#       'n_clones': 226,
#       'clone_percentage': 3.0524041058887086,
#       'purityT': 97.50101372518178,
#       'avg_purity': 95.64164750160457,
#       'avg_hiteff': 96.44959878830848,
#       'hit_eff_percentage': 96.723505683216},
#      {'label': 'long_fromb',
#       'n_reco': 656,
#       'n_particles': 679,
#       'recoeffT': 96.61266568483063,
#       'avg_recoeff': 96.61266568483063,
#       'n_clones': 14,
#       'clone_percentage': 2.1341463414634148,
#       'purityT': 97.26774137006447,
#       'avg_purity': 100.0,
#       'avg_hiteff': 97.6023976023976,
#       'hit_eff_percentage': 96.80787753723658},
#      {'label': 'long_strange',
#       'n_reco': 540,
#       'n_particles': 569,
#       'recoeffT': 94.90333919156414,
#       'avg_recoeff': 94.90333919156416,
#       'n_clones': 10,
#       'clone_percentage': 1.8518518518518519,
#       'purityT': 96.87594786456312,
#       'avg_purity': 97.22222222222221,
#       'avg_hiteff': 98.7012987012987,
#       'hit_eff_percentage': 97.98684169365984},
#      {'label': 'long_strange>5GeV',
#       'n_reco': 250,
#       'n_particles': 262,
#       'recoeffT': 95.41984732824427,
#       'avg_recoeff': 95.41984732824427,
#       'n_clones': 7,
#       'clone_percentage': 2.8,
#       'purityT': 97.07141295457903,
#       'avg_purity': 95.13888888888889,
#       'avg_hiteff': 97.72727272727273,
#       'hit_eff_percentage': 97.50395680843151},
#      {'label': 'velo',
#       'n_reco': 38070,
#       'n_particles': 41564,
#       'recoeffT': 91.59368684438456,
#       'avg_recoeff': 91.59368684438456,
#       'n_clones': 1417,
#       'clone_percentage': 3.7220908852114527,
#       'purityT': 97.94393744658181,
#       'avg_purity': 96.22790684584443,
#       'avg_hiteff': 96.67507205920306,
#       'hit_eff_percentage': 96.35714914650235}],
#     '147': [{'label': 'long_fromb>5GeV',
#       'n_reco': 526,
#       'n_particles': 545,
#       'recoeffT': 96.5137614678899,
#       'avg_recoeff': 96.5137614678899,
#       'n_clones': 12,
#       'clone_percentage': 2.2813688212927756,
#       'purityT': 97.0970775791909,
#       'avg_purity': 94.34848484848486,
#       'avg_hiteff': 98.18181818181819,
#       'hit_eff_percentage': 96.5870618105255},
#      {'label': 'long',
#       'n_reco': 11813,
#       'n_particles': 12135,
#       'recoeffT': 97.34651833539348,
#       'avg_recoeff': 97.3465183353935,
#       'n_clones': 370,
#       'clone_percentage': 3.1321425548124946,
#       'purityT': 97.56731786966056,
#       'avg_purity': 97.42162922503479,
#       'avg_hiteff': 96.4165232915233,
#       'hit_eff_percentage': 96.47390084676762},
#      {'label': 'long>5GeV',
#       'n_reco': 7451,
#       'n_particles': 7636,
#       'recoeffT': 97.57726558407543,
#       'avg_recoeff': 97.57726558407543,
#       'n_clones': 230,
#       'clone_percentage': 3.0868339820158366,
#       'purityT': 97.50085740498028,
#       'avg_purity': 97.47747067679683,
#       'avg_hiteff': 94.83769770534477,
#       'hit_eff_percentage': 96.71098273961296},
#      {'label': 'long_fromb',
#       'n_reco': 661,
#       'n_particles': 684,
#       'recoeffT': 96.6374269005848,
#       'avg_recoeff': 96.6374269005848,
#       'n_clones': 15,
#       'clone_percentage': 2.26928895612708,
#       'purityT': 97.25019103873613,
#       'avg_purity': 95.29040404040404,
#       'avg_hiteff': 98.48484848484848,
#       'hit_eff_percentage': 96.8227839456598},
#      {'label': 'long_strange',
#       'n_reco': 546,
#       'n_particles': 575,
#       'recoeffT': 94.95652173913044,
#       'avg_recoeff': 94.95652173913044,
#       'n_clones': 11,
#       'clone_percentage': 2.0146520146520146,
#       'purityT': 96.87281905637093,
#       'avg_purity': 96.62698412698413,
#       'avg_hiteff': 92.85714285714286,
#       'hit_eff_percentage': 97.92237510145945},
#      {'label': 'long_strange>5GeV',
#       'n_reco': 254,
#       'n_particles': 266,
#       'recoeffT': 95.48872180451127,
#       'avg_recoeff': 95.48872180451127,
#       'n_clones': 8,
#       'clone_percentage': 3.1496062992125986,
#       'purityT': 97.12730202033133,
#       'avg_purity': 100.0,
#       'avg_hiteff': 90.0,
#       'hit_eff_percentage': 97.36075152582787},
#      {'label': 'velo',
#       'n_reco': 38321,
#       'n_particles': 41838,
#       'recoeffT': 91.59376643242985,
#       'avg_recoeff': 91.59376643242985,
#       'n_clones': 1426,
#       'clone_percentage': 3.7211972547689256,
#       'purityT': 97.94260289212653,
#       'avg_purity': 97.7399200006815,
#       'avg_hiteff': 96.55043445116974,
#       'hit_eff_percentage': 96.35841359344312}],
#     '148': [{'label': 'long_fromb>5GeV',
#       'n_reco': 529,
#       'n_particles': 548,
#       'recoeffT': 96.53284671532846,
#       'avg_recoeff': 96.53284671532847,
#       'n_clones': 12,
#       'clone_percentage': 2.268431001890359,
#       'purityT': 97.11317511572032,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 96.6060225782448},
#      {'label': 'long',
#       'n_reco': 11932,
#       'n_particles': 12260,
#       'recoeffT': 97.32463295269169,
#       'avg_recoeff': 97.32463295269169,
#       'n_clones': 374,
#       'clone_percentage': 3.134428427757291,
#       'purityT': 97.56714298747714,
#       'avg_purity': 97.54982112048111,
#       'avg_hiteff': 96.7953463721039,
#       'hit_eff_percentage': 96.47711399586282},
#      {'label': 'long>5GeV',
#       'n_reco': 7530,
#       'n_particles': 7719,
#       'recoeffT': 97.55149630781189,
#       'avg_recoeff': 97.55149630781189,
#       'n_clones': 234,
#       'clone_percentage': 3.1075697211155378,
#       'purityT': 97.49809985870766,
#       'avg_purity': 97.2429105464187,
#       'avg_hiteff': 96.33096940857395,
#       'hit_eff_percentage': 96.70691973478542},
#      {'label': 'long_fromb',
#       'n_reco': 664,
#       'n_particles': 687,
#       'recoeffT': 96.65211062590976,
#       'avg_recoeff': 96.65211062590974,
#       'n_clones': 15,
#       'clone_percentage': 2.2590361445783134,
#       'purityT': 97.26234041559003,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 96.83684242377633},
#      {'label': 'long_strange',
#       'n_reco': 553,
#       'n_particles': 584,
#       'recoeffT': 94.6917808219178,
#       'avg_recoeff': 94.6917808219178,
#       'n_clones': 11,
#       'clone_percentage': 1.9891500904159132,
#       'purityT': 96.78797273875003,
#       'avg_purity': 90.03663003663004,
#       'avg_hiteff': 93.87755102040816,
#       'hit_eff_percentage': 97.87217338414143},
#      {'label': 'long_strange>5GeV',
#       'n_reco': 259,
#       'n_particles': 272,
#       'recoeffT': 95.22058823529412,
#       'avg_recoeff': 95.22058823529412,
#       'n_clones': 8,
#       'clone_percentage': 3.088803088803089,
#       'purityT': 96.99479228308321,
#       'avg_purity': 90.05128205128206,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 97.41017565455769},
#      {'label': 'velo',
#       'n_reco': 38712,
#       'n_particles': 42270,
#       'recoeffT': 91.58268275372605,
#       'avg_recoeff': 91.58268275372605,
#       'n_clones': 1448,
#       'clone_percentage': 3.740442240132259,
#       'purityT': 97.94229212298578,
#       'avg_purity': 97.91238379117601,
#       'avg_hiteff': 94.99374069093484,
#       'hit_eff_percentage': 96.3443784337266}],
#     '149': [{'label': 'long_fromb>5GeV',
#       'n_reco': 531,
#       'n_particles': 550,
#       'recoeffT': 96.54545454545455,
#       'avg_recoeff': 96.54545454545455,
#       'n_clones': 12,
#       'clone_percentage': 2.2598870056497176,
#       'purityT': 97.12380798822228,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 96.6185464801701},
#      {'label': 'long',
#       'n_reco': 11971,
#       'n_particles': 12300,
#       'recoeffT': 97.32520325203252,
#       'avg_recoeff': 97.32520325203252,
#       'n_clones': 375,
#       'clone_percentage': 3.132570378414502,
#       'purityT': 97.56977372744684,
#       'avg_purity': 98.37912087912088,
#       'avg_hiteff': 98.52197802197801,
#       'hit_eff_percentage': 96.48373971972224},
#      {'label': 'long>5GeV',
#       'n_reco': 7556,
#       'n_particles': 7746,
#       'recoeffT': 97.54712109475858,
#       'avg_recoeff': 97.54712109475858,
#       'n_clones': 235,
#       'clone_percentage': 3.1101111699311805,
#       'purityT': 97.50356145591147,
#       'avg_purity': 99.07407407407408,
#       'avg_hiteff': 98.07488807488808,
#       'hit_eff_percentage': 96.71166108846741},
#      {'label': 'long_fromb',
#       'n_reco': 666,
#       'n_particles': 689,
#       'recoeffT': 96.66182873730044,
#       'avg_recoeff': 96.66182873730044,
#       'n_clones': 15,
#       'clone_percentage': 2.2522522522522523,
#       'purityT': 97.2703805318438,
#       'avg_purity': 100.0,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 96.84614582841228},
#      {'label': 'long_strange',
#       'n_reco': 553,
#       'n_particles': 584,
#       'recoeffT': 94.6917808219178,
#       'avg_recoeff': 94.6917808219178,
#       'n_clones': 11,
#       'clone_percentage': 1.9891500904159132,
#       'purityT': 96.78797273875003,
#       'avg_purity': 90.03663003663004,
#       'avg_hiteff': 93.87755102040816,
#       'hit_eff_percentage': 97.87217338414143},
#      {'label': 'long_strange>5GeV',
#       'n_reco': 259,
#       'n_particles': 272,
#       'recoeffT': 95.22058823529412,
#       'avg_recoeff': 95.22058823529412,
#       'n_clones': 8,
#       'clone_percentage': 3.088803088803089,
#       'purityT': 96.99479228308321,
#       'avg_purity': 90.05128205128206,
#       'avg_hiteff': 100.0,
#       'hit_eff_percentage': 97.41017565455769},
#      {'label': 'velo',
#       'n_reco': 38857,
#       'n_particles': 42418,
#       'recoeffT': 91.60497901834127,
#       'avg_recoeff': 91.60497901834127,
#       'n_clones': 1454,
#       'clone_percentage': 3.7419255217850065,
#       'purityT': 97.94241955635016,
#       'avg_purity': 97.97631176770248,
#       'avg_hiteff': 97.53840897880633,
#       'hit_eff_percentage': 96.34885145675695}]},
#    'inference_time': 0.8743531703948975,
#    'parameters': {'max_slope': (None, None),
#     'max_tol': (None, None),
#     'scatter': 0.75}}}}

# %%
print(optimal_parameters)
# Out:
# {'scatter': 0.75, 'min_strong_track_length': 10, 'allowed_missed_modules': 2}

# %%
print(optimal_parameters)
# Out:
# {'scatter': 0.75, 'min_strong_track_length': 10, 'allowed_missed_modules': 2}

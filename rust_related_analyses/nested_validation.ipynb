# %%
from pprint import pprint
import pandas as pd
import json
import os 
import sys
import velopix_tracking as velopix 

current_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)
from py_modules.validation_to_datasets import output_distributions, output_aggregates

# %%
events = []
json_events = []
n_files = 100

for i in range(0, n_files):
    if i == 51:
        continue
    else:
        event_file = open(os.path.join("../DB/raw", f"velo_event_{i}.json"))
        json_data = json.loads(event_file.read())
        events.append(velopix.Event(json_data))
        json_events.append(json_data)
        event_file.close()

# %%
wrapper = [] # this wrapper is required because we want to eval multiple set of parameters which can be added into a list
solver = velopix.TrackFollowing(max_slopes=(0.1, 0.1), max_tolerance=(0.1, 0.1), max_scatter=0.1)
tracks = solver.solve_parallel(events=events)
results = velopix.validate_to_json_nested(json_events, tracks, verbose=False)
results["parameters"] = {
        "max_slopes": (0.1, 0.1),
        "max_tolerance": (0.1, 0.1),
        "scatter": 0.1
    }
wrapper.append(results)

# %%
pprint(wrapper, indent=4)
# Out:
# [   {   'categories': [   {   'avg_hiteff': 0.0,
#                               'avg_purity': 0.0,
#                               'avg_recoeff': 57.65765765765766,
#                               'clone_percentage': 7.8125,
#                               'hit_eff_percentage': 90.89633735248711,
#                               'label': 'long_fromb',
#                               'n_clones': 20,
#                               'n_particles': 444,
#                               'n_reco': 256,
#                               'purityT': 99.21207264957266,
#                               'recoeffT': 57.65765765765766},
#                           {   'avg_hiteff': 100.0,
#                               'avg_purity': 100.0,
#                               'avg_recoeff': 93.10344827586206,
#                               'clone_percentage': 4.320987654320987,
#                               'hit_eff_percentage': 94.51195747053735,
#                               'label': 'long_strange>5GeV',
#                               'n_clones': 7,
#                               'n_particles': 174,
#                               'n_reco': 162,
#                               'purityT': 99.62242885319809,
#                               'recoeffT': 93.10344827586206},
#                           {   'avg_hiteff': 90.36780987212016,
#                               'avg_purity': 99.51970443349755,
#                               'avg_recoeff': 54.01769785199457,
#                               'clone_percentage': 7.497192681154634,
#                               'hit_eff_percentage': 90.48048342177218,
#                               'label': 'velo',
#                               'n_clones': 1135,
#                               'n_particles': 28026,
#                               'n_reco': 15139,
#                               'purityT': 99.64690801231406,
#                               'recoeffT': 54.017697851994576},
#                           {   'avg_hiteff': 91.54411764705883,
#                               'avg_purity': 99.52731092436974,
#                               'avg_recoeff': 88.45098039215686,
#                               'clone_percentage': 7.891819995566394,
#                               'hit_eff_percentage': 91.54205920140073,
#                               'label': 'long>5GeV',
#                               'n_clones': 356,
#                               'n_particles': 5100,
#                               'n_reco': 4511,
#                               'purityT': 99.6851845446976,
#                               'recoeffT': 88.45098039215686},
#                           {   'avg_hiteff': 0.0,
#                               'avg_purity': 0.0,
#                               'avg_recoeff': 61.224489795918366,
#                               'clone_percentage': 7.142857142857143,
#                               'hit_eff_percentage': 91.71515364595722,
#                               'label': 'long_fromb>5GeV',
#                               'n_clones': 15,
#                               'n_particles': 343,
#                               'n_reco': 210,
#                               'purityT': 99.03347578347578,
#                               'recoeffT': 61.224489795918366},
#                           {   'avg_hiteff': 89.16351010101009,
#                               'avg_purity': 99.59821428571429,
#                               'avg_recoeff': 75.13620604259535,
#                               'clone_percentage': 10.299934080421885,
#                               'hit_eff_percentage': 89.14775989305103,
#                               'label': 'long',
#                               'n_clones': 625,
#                               'n_particles': 8076,
#                               'n_reco': 6068,
#                               'purityT': 99.6995974500457,
#                               'recoeffT': 75.13620604259535},
#                           {   'avg_hiteff': 77.77777777777777,
#                               'avg_purity': 100.0,
#                               'avg_recoeff': 73.24675324675324,
#                               'clone_percentage': 8.156028368794326,
#                               'hit_eff_percentage': 89.57426908246583,
#                               'label': 'long_strange',
#                               'n_clones': 23,
#                               'n_particles': 385,
#                               'n_reco': 282,
#                               'purityT': 99.6432474629196,
#                               'recoeffT': 73.24675324675324}],
#         'event_avg_ghost_rate': 1.0848471523441274,
#         'events': {   '1': [   {   'avg_hiteff': 89.78402799446708,
#                                    'avg_purity': 99.6830985915493,
#                                    'avg_recoeff': 56.65236051502146,
#                                    'clone_percentage': 7.575757575757576,
#                                    'hit_eff_percentage': 89.78402799446708,
#                                    'label': 'velo',
#                                    'n_clones': 10,
#                                    'n_particles': 233,
#                                    'n_reco': 132,
#                                    'purityT': 99.68309859154931,
#                                    'recoeffT': 56.652360515021456},
#                                {   'avg_hiteff': 100.0,
#                                    'avg_purity': 100.0,
#                                    'avg_recoeff': 100.0,
#                                    'clone_percentage': 0.0,
#                                    'hit_eff_percentage': 100.0,
#                                    'label': 'long_fromb',
#                                    'n_clones': 0,
#                                    'n_particles': 4,
#                                    'n_reco': 4,
#                                    'purityT': 100.0,
#                                    'recoeffT': 100.0},
#                                {   'avg_hiteff': 100.0,
#                                    'avg_purity': 100.0,
#                                    'avg_recoeff': 100.0,
#                                    'clone_percentage': 0.0,
#                                    'hit_eff_percentage': 100.0,
#                                    'label': 'long_fromb>5GeV',
#                                    'n_clones': 0,
#                                    'n_particles': 3,
#                                    'n_reco': 3,
#                                    'purityT': 100.0,
#                                    'recoeffT': 100.0},
#                                {   'avg_hiteff': 94.58333333333333,
#                                    'avg_purity': 99.58333333333333,
#                                    'avg_recoeff': 100.0,
#                                    'clone_percentage': 4.3478260869565215,
#                                    'hit_eff_percentage': 94.58333333333333,
#                                    'label': 'long>5GeV',
#                                    'n_clones': 2,
#                                    'n_particles': 46,
#                                    'n_reco': 46,
#                                    'purityT': 99.58333333333333,
#                                    'recoeffT': 100.0},
#                                {   'avg_hiteff': 92.37750172532783,
#                                    'avg_purity': 99.71014492753622,
#                                    'avg_recoeff': 82.27848101265823,
#                                    'clone_percentage': 6.153846153846154,
#                                    'hit_eff_percentage': 92.37750172532783,
#                                    'label': 'long',
#                                    'n_clones': 4,
#                                    'n_particles': 79,
#                                    'n_reco': 65,
#                                    'purityT': 99.71014492753623,
#                                    'recoeffT': 82.27848101265823},
#                                {   'avg_hiteff': 100.0,
#                                    'avg_purity': 100.0,
#                                    'avg_recoeff': 33.33333333333333,
#                                    'clone_percentage': 0.0,
#                                    'hit_eff_percentage': 100.0,
#                                    'label': 'long_strange',
#                                    'n_clones': 0,
#                                    'n_particles': 3,
#                                    'n_reco': 1,
#                                    'purityT': 100.0,
#                                    'recoeffT': 33.333333333333336}],
#                       '10': [   {   'avg_hiteff': 90.76727461973364,
#                                     'avg_purity': 99.73360655737704,
#                                     'avg_recoeff': 55.80286168521462,
#                                     'clone_percentage': 7.478632478632479,
#                                     'hit_eff_percentage': 90.400388803061,
#                                     'label': 'velo',
#                                     'n_clones': 105,
#                                     'n_particles': 2516,
#                                     'n_reco': 1404,
#                                     'purityT': 99.68442830271857,
#                                     'recoeffT': 55.80286168521462},
#                                 {   'avg_hiteff': 94.44444444444446,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 54.166666666666664,
#                                     'clone_percentage': 7.6923076923076925,
#                                     'hit_eff_percentage': 89.88683935112506,
#                                     'label': 'long_fromb',
#                                     'n_clones': 2,
#                                     'n_particles': 48,
#                                     'n_reco': 26,
#                                     'purityT': 98.69047619047619,
#                                     'recoeffT': 54.166666666666664},
#                                 {   'avg_hiteff': 0.0,
#                                     'avg_purity': 0.0,
#                                     'avg_recoeff': 54.054054054054056,
#                                     'clone_percentage': 5.0,
#                                     'hit_eff_percentage': 92.43764172335602,
#                                     'label': 'long_fromb>5GeV',
#                                     'n_clones': 1,
#                                     'n_particles': 37,
#                                     'n_reco': 20,
#                                     'purityT': 98.25396825396827,
#                                     'recoeffT': 54.054054054054056},
#                                 {   'avg_hiteff': 100.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 100.0,
#                                     'clone_percentage': 9.090909090909092,
#                                     'hit_eff_percentage': 91.66666666666667,
#                                     'label': 'long_strange>5GeV',
#                                     'n_clones': 1,
#                                     'n_particles': 11,
#                                     'n_reco': 11,
#                                     'purityT': 100.0,
#                                     'recoeffT': 100.0},
#                                 {   'avg_hiteff': 85.38295038295037,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 89.171974522293,
#                                     'clone_percentage': 8.333333333333334,
#                                     'hit_eff_percentage': 91.06063564030596,
#                                     'label': 'long>5GeV',
#                                     'n_clones': 35,
#                                     'n_particles': 471,
#                                     'n_reco': 420,
#                                     'purityT': 99.76712176712178,
#                                     'recoeffT': 89.171974522293},
#                                 {   'avg_hiteff': 84.55054749172398,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 76.69376693766937,
#                                     'clone_percentage': 10.954063604240282,
#                                     'hit_eff_percentage': 88.63310322904272,
#                                     'label': 'long',
#                                     'n_clones': 62,
#                                     'n_particles': 738,
#                                     'n_reco': 566,
#                                     'purityT': 99.76758026121084,
#                                     'recoeffT': 76.69376693766938},
#                                 {   'avg_hiteff': 0.0,
#                                     'avg_purity': 0.0,
#                                     'avg_recoeff': 66.66666666666666,
#                                     'clone_percentage': 10.0,
#                                     'hit_eff_percentage': 89.77272727272727,
#                                     'label': 'long_strange',
#                                     'n_clones': 2,
#                                     'n_particles': 30,
#                                     'n_reco': 20,
#                                     'purityT': 100.0,
#                                     'recoeffT': 66.66666666666667}],
#                       '11': [   {   'avg_hiteff': 89.94922886898196,
#                                     'avg_purity': 99.81318178849044,
#                                     'avg_recoeff': 55.5744971019434,
#                                     'clone_percentage': 7.484662576687117,
#                                     'hit_eff_percentage': 90.33781353823154,
#                                     'label': 'velo',
#                                     'n_clones': 122,
#                                     'n_particles': 2933,
#                                     'n_reco': 1630,
#                                     'purityT': 99.70228623482048,
#                                     'recoeffT': 55.5744971019434},
#                                 {   'avg_hiteff': 95.55555555555554,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 58.490566037735846,
#                                     'clone_percentage': 6.451612903225806,
#                                     'hit_eff_percentage': 90.74573574573574,
#                                     'label': 'long_fromb',
#                                     'n_clones': 2,
#                                     'n_particles': 53,
#                                     'n_reco': 31,
#                                     'purityT': 98.8888888888889,
#                                     'recoeffT': 58.490566037735846},
#                                 {   'avg_hiteff': 94.44444444444444,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 58.536585365853654,
#                                     'clone_percentage': 4.166666666666667,
#                                     'hit_eff_percentage': 92.75873015873017,
#                                     'label': 'long_fromb>5GeV',
#                                     'n_clones': 1,
#                                     'n_particles': 41,
#                                     'n_reco': 24,
#                                     'purityT': 98.53333333333335,
#                                     'recoeffT': 58.53658536585366},
#                                 {   'avg_hiteff': 100.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 100.0,
#                                     'clone_percentage': 7.6923076923076925,
#                                     'hit_eff_percentage': 92.85714285714286,
#                                     'label': 'long_strange>5GeV',
#                                     'n_clones': 1,
#                                     'n_particles': 13,
#                                     'n_reco': 13,
#                                     'purityT': 100.0,
#                                     'recoeffT': 100.0},
#                                 {   'avg_hiteff': 90.85159285159286,
#                                     'avg_purity': 99.60927960927961,
#                                     'avg_recoeff': 89.3854748603352,
#                                     'clone_percentage': 8.333333333333334,
#                                     'hit_eff_percentage': 91.03450529171684,
#                                     'label': 'long>5GeV',
#                                     'n_clones': 40,
#                                     'n_particles': 537,
#                                     'n_reco': 480,
#                                     'purityT': 99.7473914973915,
#                                     'recoeffT': 89.3854748603352},
#                                 {   'avg_hiteff': 88.42544677544679,
#                                     'avg_purity': 99.74603174603175,
#                                     'avg_recoeff': 76.81498829039812,
#                                     'clone_percentage': 10.975609756097562,
#                                     'hit_eff_percentage': 88.6045789909114,
#                                     'label': 'long',
#                                     'n_clones': 72,
#                                     'n_particles': 854,
#                                     'n_reco': 656,
#                                     'purityT': 99.76462030033458,
#                                     'recoeffT': 76.81498829039812},
#                                 {   'avg_hiteff': 95.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 67.56756756756756,
#                                     'clone_percentage': 8.0,
#                                     'hit_eff_percentage': 90.74074074074075,
#                                     'label': 'long_strange',
#                                     'n_clones': 2,
#                                     'n_particles': 37,
#                                     'n_reco': 25,
#                                     'purityT': 100.0,
#                                     'recoeffT': 67.56756756756756}],
#                       '12': [   {   'avg_hiteff': 92.11965811965813,
#                                     'avg_purity': 99.6923076923077,
#                                     'avg_recoeff': 55.370006548788474,
#                                     'clone_percentage': 7.451212300413956,
#                                     'hit_eff_percentage': 90.40155591456217,
#                                     'label': 'velo',
#                                     'n_clones': 126,
#                                     'n_particles': 3054,
#                                     'n_reco': 1691,
#                                     'purityT': 99.70192926989846,
#                                     'recoeffT': 55.370006548788474},
#                                 {   'avg_hiteff': 100.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 60.71428571428571,
#                                     'clone_percentage': 5.882352941176471,
#                                     'hit_eff_percentage': 91.5169244335911,
#                                     'label': 'long_fromb',
#                                     'n_clones': 2,
#                                     'n_particles': 56,
#                                     'n_reco': 34,
#                                     'purityT': 98.98148148148148,
#                                     'recoeffT': 60.714285714285715},
#                                 {   'avg_hiteff': 100.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 60.46511627906976,
#                                     'clone_percentage': 3.8461538461538463,
#                                     'hit_eff_percentage': 93.29512051734275,
#                                     'label': 'long_fromb>5GeV',
#                                     'n_clones': 1,
#                                     'n_particles': 43,
#                                     'n_reco': 26,
#                                     'purityT': 98.64197530864197,
#                                     'recoeffT': 60.46511627906977},
#                                 {   'avg_hiteff': 100.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 100.0,
#                                     'clone_percentage': 7.142857142857143,
#                                     'hit_eff_percentage': 93.33333333333333,
#                                     'label': 'long_strange>5GeV',
#                                     'n_clones': 1,
#                                     'n_particles': 14,
#                                     'n_reco': 14,
#                                     'purityT': 100.0,
#                                     'recoeffT': 100.0},
#                                 {   'avg_hiteff': 100.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 89.62432915921288,
#                                     'clone_percentage': 7.984031936127744,
#                                     'hit_eff_percentage': 91.3825189495245,
#                                     'label': 'long>5GeV',
#                                     'n_clones': 40,
#                                     'n_particles': 559,
#                                     'n_reco': 501,
#                                     'purityT': 99.75719700303804,
#                                     'recoeffT': 89.62432915921288},
#                                 {   'avg_hiteff': 99.78494623655914,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 76.84563758389261,
#                                     'clone_percentage': 10.480349344978166,
#                                     'hit_eff_percentage': 89.06122113137923,
#                                     'label': 'long',
#                                     'n_clones': 72,
#                                     'n_particles': 894,
#                                     'n_reco': 687,
#                                     'purityT': 99.77423396395729,
#                                     'recoeffT': 76.84563758389261},
#                                 {   'avg_hiteff': 100.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 61.36363636363637,
#                                     'clone_percentage': 7.407407407407407,
#                                     'hit_eff_percentage': 91.37931034482759,
#                                     'label': 'long_strange',
#                                     'n_clones': 2,
#                                     'n_particles': 44,
#                                     'n_reco': 27,
#                                     'purityT': 100.0,
#                                     'recoeffT': 61.36363636363637}],
#                       '13': [   {   'avg_hiteff': 91.286181766951,
#                                     'avg_purity': 99.61538461538461,
#                                     'avg_recoeff': 54.660023446658855,
#                                     'clone_percentage': 7.238605898123325,
#                                     'hit_eff_percentage': 90.48209713774114,
#                                     'label': 'velo',
#                                     'n_clones': 135,
#                                     'n_particles': 3412,
#                                     'n_reco': 1865,
#                                     'purityT': 99.64420274170274,
#                                     'recoeffT': 54.660023446658855},
#                                 {   'avg_hiteff': 70.83333333333334,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 61.29032258064516,
#                                     'clone_percentage': 7.894736842105263,
#                                     'hit_eff_percentage': 89.44856532356533,
#                                     'label': 'long_fromb',
#                                     'n_clones': 3,
#                                     'n_particles': 62,
#                                     'n_reco': 38,
#                                     'purityT': 96.66666666666667,
#                                     'recoeffT': 61.29032258064516},
#                                 {   'avg_hiteff': 66.66666666666666,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 61.702127659574465,
#                                     'clone_percentage': 6.896551724137931,
#                                     'hit_eff_percentage': 90.63227513227515,
#                                     'label': 'long_fromb>5GeV',
#                                     'n_clones': 2,
#                                     'n_particles': 47,
#                                     'n_reco': 29,
#                                     'purityT': 95.59139784946237,
#                                     'recoeffT': 61.702127659574465},
#                                 {   'avg_hiteff': 100.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 100.0,
#                                     'clone_percentage': 7.142857142857143,
#                                     'hit_eff_percentage': 93.33333333333333,
#                                     'label': 'long_strange>5GeV',
#                                     'n_clones': 1,
#                                     'n_particles': 14,
#                                     'n_reco': 14,
#                                     'purityT': 100.0,
#                                     'recoeffT': 100.0},
#                                 {   'avg_hiteff': 89.41058941058941,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 90.0,
#                                     'clone_percentage': 8.19672131147541,
#                                     'hit_eff_percentage': 91.20960101356391,
#                                     'label': 'long>5GeV',
#                                     'n_clones': 45,
#                                     'n_particles': 610,
#                                     'n_reco': 549,
#                                     'purityT': 99.61051107515755,
#                                     'recoeffT': 90.0},
#                                 {   'avg_hiteff': 90.16532673675529,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 76.89161554192229,
#                                     'clone_percentage': 10.372340425531915,
#                                     'hit_eff_percentage': 89.15445079648939,
#                                     'label': 'long',
#                                     'n_clones': 78,
#                                     'n_particles': 978,
#                                     'n_reco': 752,
#                                     'purityT': 99.67306455258262,
#                                     'recoeffT': 76.89161554192229},
#                                 {   'avg_hiteff': 100.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 62.22222222222222,
#                                     'clone_percentage': 7.142857142857143,
#                                     'hit_eff_percentage': 91.66666666666667,
#                                     'label': 'long_strange',
#                                     'n_clones': 2,
#                                     'n_particles': 45,
#                                     'n_reco': 28,
#                                     'purityT': 100.0,
#                                     'recoeffT': 62.22222222222222}],
#                       '14': [   {   'avg_hiteff': 92.04091072098063,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 54.72473294987674,
#                                     'clone_percentage': 7.257257257257257,
#                                     'hit_eff_percentage': 90.5861635907772,
#                                     'label': 'velo',
#                                     'n_clones': 145,
#                                     'n_particles': 3651,
#                                     'n_reco': 1998,
#                                     'purityT': 99.66794469594284,
#                                     'recoeffT': 54.724732949876746},
#                                 {   'avg_hiteff': 0.0,
#                                     'avg_purity': 0.0,
#                                     'avg_recoeff': 59.375,
#                                     'clone_percentage': 7.894736842105263,
#                                     'hit_eff_percentage': 89.44856532356533,
#                                     'label': 'long_fromb',
#                                     'n_clones': 3,
#                                     'n_particles': 64,
#                                     'n_reco': 38,
#                                     'purityT': 96.66666666666667,
#                                     'recoeffT': 59.375},
#                                 {   'avg_hiteff': 0.0,
#                                     'avg_purity': 0.0,
#                                     'avg_recoeff': 59.183673469387756,
#                                     'clone_percentage': 6.896551724137931,
#                                     'hit_eff_percentage': 90.63227513227515,
#                                     'label': 'long_fromb>5GeV',
#                                     'n_clones': 2,
#                                     'n_particles': 49,
#                                     'n_reco': 29,
#                                     'purityT': 95.59139784946237,
#                                     'recoeffT': 59.183673469387756},
#                                 {   'avg_hiteff': 100.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 100.0,
#                                     'clone_percentage': 6.666666666666667,
#                                     'hit_eff_percentage': 93.75,
#                                     'label': 'long_strange>5GeV',
#                                     'n_clones': 1,
#                                     'n_particles': 15,
#                                     'n_reco': 15,
#                                     'purityT': 100.0,
#                                     'recoeffT': 100.0},
#                                 {   'avg_hiteff': 89.96636866534823,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 89.98482549317147,
#                                     'clone_percentage': 8.431703204047217,
#                                     'hit_eff_percentage': 91.11471256331069,
#                                     'label': 'long>5GeV',
#                                     'n_clones': 50,
#                                     'n_particles': 659,
#                                     'n_reco': 593,
#                                     'purityT': 99.64019219073653,
#                                     'recoeffT': 89.98482549317147},
#                                 {   'avg_hiteff': 89.53234265734265,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 76.42585551330798,
#                                     'clone_percentage': 10.447761194029852,
#                                     'hit_eff_percentage': 89.17916074905928,
#                                     'label': 'long',
#                                     'n_clones': 84,
#                                     'n_particles': 1052,
#                                     'n_reco': 804,
#                                     'purityT': 99.69441844441845,
#                                     'recoeffT': 76.42585551330798},
#                                 {   'avg_hiteff': 100.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 61.702127659574465,
#                                     'clone_percentage': 6.896551724137931,
#                                     'hit_eff_percentage': 91.93548387096774,
#                                     'label': 'long_strange',
#                                     'n_clones': 2,
#                                     'n_particles': 47,
#                                     'n_reco': 29,
#                                     'purityT': 100.0,
#                                     'recoeffT': 61.702127659574465}],
#                       '15': [   {   'avg_hiteff': 89.59894080447442,
#                                     'avg_purity': 99.77914378112006,
#                                     'avg_recoeff': 54.891838741396256,
#                                     'clone_percentage': 7.299596954769369,
#                                     'hit_eff_percentage': 90.4818765908045,
#                                     'label': 'velo',
#                                     'n_clones': 163,
#                                     'n_particles': 4068,
#                                     'n_reco': 2233,
#                                     'purityT': 99.67968650251623,
#                                     'recoeffT': 54.89183874139626},
#                                 {   'avg_hiteff': 100.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 58.2089552238806,
#                                     'clone_percentage': 7.6923076923076925,
#                                     'hit_eff_percentage': 89.70591738884423,
#                                     'label': 'long_fromb',
#                                     'n_clones': 3,
#                                     'n_particles': 67,
#                                     'n_reco': 39,
#                                     'purityT': 96.74603174603175,
#                                     'recoeffT': 58.208955223880594},
#                                 {   'avg_hiteff': 100.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 58.82352941176471,
#                                     'clone_percentage': 6.666666666666667,
#                                     'hit_eff_percentage': 90.93445980542757,
#                                     'label': 'long_fromb>5GeV',
#                                     'n_clones': 2,
#                                     'n_particles': 51,
#                                     'n_reco': 30,
#                                     'purityT': 95.72916666666667,
#                                     'recoeffT': 58.8235294117647},
#                                 {   'avg_hiteff': 100.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 100.0,
#                                     'clone_percentage': 5.882352941176471,
#                                     'hit_eff_percentage': 94.44444444444444,
#                                     'label': 'long_strange>5GeV',
#                                     'n_clones': 1,
#                                     'n_particles': 17,
#                                     'n_reco': 17,
#                                     'purityT': 100.0,
#                                     'recoeffT': 100.0},
#                                 {   'avg_hiteff': 92.24021913046302,
#                                     'avg_purity': 99.6733449477352,
#                                     'avg_recoeff': 90.54054054054053,
#                                     'clone_percentage': 8.208955223880597,
#                                     'hit_eff_percentage': 91.24218706401027,
#                                     'label': 'long>5GeV',
#                                     'n_clones': 55,
#                                     'n_particles': 740,
#                                     'n_reco': 670,
#                                     'purityT': 99.64394188187292,
#                                     'recoeffT': 90.54054054054055},
#                                 {   'avg_hiteff': 89.13116367063736,
#                                     'avg_purity': 99.76503759398496,
#                                     'avg_recoeff': 76.81895093062606,
#                                     'clone_percentage': 10.352422907488986,
#                                     'hit_eff_percentage': 89.17369454831992,
#                                     'label': 'long',
#                                     'n_clones': 94,
#                                     'n_particles': 1182,
#                                     'n_reco': 908,
#                                     'purityT': 99.70245295844099,
#                                     'recoeffT': 76.81895093062606},
#                                 {   'avg_hiteff': 100.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 60.78431372549019,
#                                     'clone_percentage': 6.451612903225806,
#                                     'hit_eff_percentage': 92.42424242424242,
#                                     'label': 'long_strange',
#                                     'n_clones': 2,
#                                     'n_particles': 51,
#                                     'n_reco': 31,
#                                     'purityT': 100.0,
#                                     'recoeffT': 60.78431372549019}],
#                       '16': [   {   'avg_hiteff': 88.41957253124765,
#                                     'avg_purity': 99.5346869712352,
#                                     'avg_recoeff': 54.65880752663795,
#                                     'clone_percentage': 7.548734964744919,
#                                     'hit_eff_percentage': 90.32513511714218,
#                                     'label': 'velo',
#                                     'n_clones': 182,
#                                     'n_particles': 4411,
#                                     'n_reco': 2411,
#                                     'purityT': 99.6686703406719,
#                                     'recoeffT': 54.65880752663795},
#                                 {   'avg_hiteff': 0.0,
#                                     'avg_purity': 0.0,
#                                     'avg_recoeff': 57.35294117647059,
#                                     'clone_percentage': 7.6923076923076925,
#                                     'hit_eff_percentage': 89.70591738884423,
#                                     'label': 'long_fromb',
#                                     'n_clones': 3,
#                                     'n_particles': 68,
#                                     'n_reco': 39,
#                                     'purityT': 96.74603174603175,
#                                     'recoeffT': 57.35294117647059},
#                                 {   'avg_hiteff': 0.0,
#                                     'avg_purity': 0.0,
#                                     'avg_recoeff': 57.692307692307686,
#                                     'clone_percentage': 6.666666666666667,
#                                     'hit_eff_percentage': 90.93445980542757,
#                                     'label': 'long_fromb>5GeV',
#                                     'n_clones': 2,
#                                     'n_particles': 52,
#                                     'n_reco': 30,
#                                     'purityT': 95.72916666666667,
#                                     'recoeffT': 57.69230769230769},
#                                 {   'avg_hiteff': 100.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 100.0,
#                                     'clone_percentage': 5.555555555555555,
#                                     'hit_eff_percentage': 94.73684210526316,
#                                     'label': 'long_strange>5GeV',
#                                     'n_clones': 1,
#                                     'n_particles': 18,
#                                     'n_reco': 18,
#                                     'purityT': 100.0,
#                                     'recoeffT': 100.0},
#                                 {   'avg_hiteff': 94.39153439153438,
#                                     'avg_purity': 99.60317460317461,
#                                     'avg_recoeff': 90.23485784919654,
#                                     'clone_percentage': 7.945205479452055,
#                                     'hit_eff_percentage': 91.49429491869137,
#                                     'label': 'long>5GeV',
#                                     'n_clones': 58,
#                                     'n_particles': 809,
#                                     'n_reco': 730,
#                                     'purityT': 99.64068256898206,
#                                     'recoeffT': 90.23485784919654},
#                                 {   'avg_hiteff': 88.80021141649048,
#                                     'avg_purity': 99.59302325581396,
#                                     'avg_recoeff': 76.53457653457653,
#                                     'clone_percentage': 10.456852791878173,
#                                     'hit_eff_percentage': 89.14414574488171,
#                                     'label': 'long',
#                                     'n_clones': 103,
#                                     'n_particles': 1287,
#                                     'n_reco': 985,
#                                     'purityT': 99.69380318415244,
#                                     'recoeffT': 76.53457653457653},
#                                 {   'avg_hiteff': 88.88888888888889,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 62.96296296296296,
#                                     'clone_percentage': 5.882352941176471,
#                                     'hit_eff_percentage': 92.12962962962962,
#                                     'label': 'long_strange',
#                                     'n_clones': 2,
#                                     'n_particles': 54,
#                                     'n_reco': 34,
#                                     'purityT': 100.0,
#                                     'recoeffT': 62.96296296296296}],
#                       '17': [   {   'avg_hiteff': 89.17962081777871,
#                                     'avg_purity': 99.6842105263158,
#                                     'avg_recoeff': 55.294117647058826,
#                                     'clone_percentage': 7.659574468085107,
#                                     'hit_eff_percentage': 90.24690085514398,
#                                     'label': 'velo',
#                                     'n_clones': 198,
#                                     'n_particles': 4675,
#                                     'n_reco': 2585,
#                                     'purityT': 99.66973129477624,
#                                     'recoeffT': 55.294117647058826},
#                                 {   'avg_hiteff': 50.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 56.33802816901409,
#                                     'clone_percentage': 10.0,
#                                     'hit_eff_percentage': 87.85913053354915,
#                                     'label': 'long_fromb',
#                                     'n_clones': 4,
#                                     'n_particles': 71,
#                                     'n_reco': 40,
#                                     'purityT': 96.89393939393939,
#                                     'recoeffT': 56.33802816901409},
#                                 {   'avg_hiteff': 50.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 58.490566037735846,
#                                     'clone_percentage': 9.67741935483871,
#                                     'hit_eff_percentage': 88.45358345358346,
#                                     'label': 'long_fromb>5GeV',
#                                     'n_clones': 3,
#                                     'n_particles': 53,
#                                     'n_reco': 31,
#                                     'purityT': 95.98039215686275,
#                                     'recoeffT': 58.490566037735846},
#                                 {   'avg_hiteff': 95.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 95.65217391304348,
#                                     'clone_percentage': 4.545454545454546,
#                                     'hit_eff_percentage': 94.78260869565217,
#                                     'label': 'long_strange>5GeV',
#                                     'n_clones': 1,
#                                     'n_particles': 23,
#                                     'n_reco': 22,
#                                     'purityT': 100.0,
#                                     'recoeffT': 95.65217391304348},
#                                 {   'avg_hiteff': 89.0693722943723,
#                                     'avg_purity': 99.6,
#                                     'avg_recoeff': 90.23255813953487,
#                                     'clone_percentage': 7.989690721649485,
#                                     'hit_eff_percentage': 91.3494369363545,
#                                     'label': 'long>5GeV',
#                                     'n_clones': 62,
#                                     'n_particles': 860,
#                                     'n_reco': 776,
#                                     'purityT': 99.63825520806428,
#                                     'recoeffT': 90.23255813953489},
#                                 {   'avg_hiteff': 82.99816545243375,
#                                     'avg_purity': 99.7560975609756,
#                                     'avg_recoeff': 76.78311499272198,
#                                     'clone_percentage': 10.90047393364929,
#                                     'hit_eff_percentage': 88.7130333548212,
#                                     'label': 'long',
#                                     'n_clones': 115,
#                                     'n_particles': 1374,
#                                     'n_reco': 1055,
#                                     'purityT': 99.69816911483578,
#                                     'recoeffT': 76.78311499272198},
#                                 {   'avg_hiteff': 85.00000000000001,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 66.12903225806451,
#                                     'clone_percentage': 7.317073170731708,
#                                     'hit_eff_percentage': 90.83333333333334,
#                                     'label': 'long_strange',
#                                     'n_clones': 3,
#                                     'n_particles': 62,
#                                     'n_reco': 41,
#                                     'purityT': 100.0,
#                                     'recoeffT': 66.12903225806451}],
#                       '18': [   {   'avg_hiteff': 85.289874267147,
#                                     'avg_purity': 99.28977272727273,
#                                     'avg_recoeff': 55.375337908088994,
#                                     'clone_percentage': 7.810739767179872,
#                                     'hit_eff_percentage': 90.09490840227159,
#                                     'label': 'velo',
#                                     'n_clones': 208,
#                                     'n_particles': 4809,
#                                     'n_reco': 2663,
#                                     'purityT': 99.65808505515928,
#                                     'recoeffT': 55.375337908089},
#                                 {   'avg_hiteff': 70.23809523809524,
#                                     'avg_purity': 98.21428571428571,
#                                     'avg_recoeff': 57.692307692307686,
#                                     'clone_percentage': 13.333333333333334,
#                                     'hit_eff_percentage': 85.3921855921856,
# ...
#                                     'n_clones': 601,
#                                     'n_particles': 7751,
#                                     'n_reco': 5825,
#                                     'purityT': 99.70170238085738,
#                                     'recoeffT': 75.15159334279448},
#                                 {   'avg_hiteff': 100.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 73.09782608695652,
#                                     'clone_percentage': 7.063197026022305,
#                                     'hit_eff_percentage': 90.56545306545308,
#                                     'label': 'long_strange',
#                                     'n_clones': 19,
#                                     'n_particles': 368,
#                                     'n_reco': 269,
#                                     'purityT': 99.62218915343917,
#                                     'recoeffT': 73.09782608695652}],
#                       '97': [   {   'avg_hiteff': 92.3702634813746,
#                                     'avg_purity': 99.61399711399713,
#                                     'avg_recoeff': 54.07233166715672,
#                                     'clone_percentage': 7.517672648178358,
#                                     'hit_eff_percentage': 90.48661569268333,
#                                     'label': 'velo',
#                                     'n_clones': 1106,
#                                     'n_particles': 27208,
#                                     'n_reco': 14712,
#                                     'purityT': 99.64740862080083,
#                                     'recoeffT': 54.07233166715672},
#                                 {   'avg_hiteff': 100.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 58.87850467289719,
#                                     'clone_percentage': 7.936507936507937,
#                                     'hit_eff_percentage': 90.79886631709947,
#                                     'label': 'long_fromb',
#                                     'n_clones': 20,
#                                     'n_particles': 428,
#                                     'n_reco': 252,
#                                     'purityT': 99.20048548265461,
#                                     'recoeffT': 58.87850467289719},
#                                 {   'avg_hiteff': 100.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 62.16216216216216,
#                                     'clone_percentage': 7.246376811594203,
#                                     'hit_eff_percentage': 91.60268966830053,
#                                     'label': 'long_fromb>5GeV',
#                                     'n_clones': 15,
#                                     'n_particles': 333,
#                                     'n_reco': 207,
#                                     'purityT': 99.02041464541465,
#                                     'recoeffT': 62.16216216216216},
#                                 {   'avg_hiteff': 100.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 92.89940828402366,
#                                     'clone_percentage': 3.821656050955414,
#                                     'hit_eff_percentage': 94.96726177707774,
#                                     'label': 'long_strange>5GeV',
#                                     'n_clones': 6,
#                                     'n_particles': 169,
#                                     'n_reco': 157,
#                                     'purityT': 99.60853052877594,
#                                     'recoeffT': 92.89940828402366},
#                                 {   'avg_hiteff': 95.33788515406162,
#                                     'avg_purity': 99.57219251336898,
#                                     'avg_recoeff': 88.47628657921291,
#                                     'clone_percentage': 7.91514598540146,
#                                     'hit_eff_percentage': 91.53320357952617,
#                                     'label': 'long>5GeV',
#                                     'n_clones': 347,
#                                     'n_particles': 4955,
#                                     'n_reco': 4384,
#                                     'purityT': 99.68557092288863,
#                                     'recoeffT': 88.47628657921291},
#                                 {   'avg_hiteff': 91.64546256212925,
#                                     'avg_purity': 99.67676767676767,
#                                     'avg_recoeff': 75.22281639928698,
#                                     'clone_percentage': 10.291130670277589,
#                                     'hit_eff_percentage': 89.15504237165607,
#                                     'label': 'long',
#                                     'n_clones': 608,
#                                     'n_particles': 7854,
#                                     'n_reco': 5908,
#                                     'purityT': 99.7013579788672,
#                                     'recoeffT': 75.22281639928698},
#                                 {   'avg_hiteff': 80.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 73.19034852546918,
#                                     'clone_percentage': 7.326007326007326,
#                                     'hit_eff_percentage': 90.38515523157163,
#                                     'label': 'long_strange',
#                                     'n_clones': 20,
#                                     'n_particles': 373,
#                                     'n_reco': 273,
#                                     'purityT': 99.62863643751017,
#                                     'recoeffT': 73.19034852546918}],
#                       '98': [   {   'avg_hiteff': 90.16422627471735,
#                                     'avg_purity': 99.74330357142858,
#                                     'avg_recoeff': 54.093249220506124,
#                                     'clone_percentage': 7.520107238605898,
#                                     'hit_eff_percentage': 90.48211321561963,
#                                     'label': 'velo',
#                                     'n_clones': 1122,
#                                     'n_particles': 27582,
#                                     'n_reco': 14920,
#                                     'purityT': 99.64874763519683,
#                                     'recoeffT': 54.093249220506124},
#                                 {   'avg_hiteff': 97.5,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 58.31435079726651,
#                                     'clone_percentage': 7.8125,
#                                     'hit_eff_percentage': 90.89633735248711,
#                                     'label': 'long_fromb',
#                                     'n_clones': 20,
#                                     'n_particles': 439,
#                                     'n_reco': 256,
#                                     'purityT': 99.21207264957266,
#                                     'recoeffT': 58.31435079726651},
#                                 {   'avg_hiteff': 100.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 61.58357771260997,
#                                     'clone_percentage': 7.142857142857143,
#                                     'hit_eff_percentage': 91.71515364595722,
#                                     'label': 'long_fromb>5GeV',
#                                     'n_clones': 15,
#                                     'n_particles': 341,
#                                     'n_reco': 210,
#                                     'purityT': 99.03347578347578,
#                                     'recoeffT': 61.58357771260997},
#                                 {   'avg_hiteff': 64.28571428571428,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 92.98245614035088,
#                                     'clone_percentage': 4.40251572327044,
#                                     'hit_eff_percentage': 94.41277597904103,
#                                     'label': 'long_strange>5GeV',
#                                     'n_clones': 7,
#                                     'n_particles': 171,
#                                     'n_reco': 159,
#                                     'purityT': 99.61560527825588,
#                                     'recoeffT': 92.98245614035088},
#                                 {   'avg_hiteff': 92.15598739495799,
#                                     'avg_purity': 99.81617647058823,
#                                     'avg_recoeff': 88.46230356077183,
#                                     'clone_percentage': 7.915448617045199,
#                                     'hit_eff_percentage': 91.54203002793163,
#                                     'label': 'long>5GeV',
#                                     'n_clones': 352,
#                                     'n_particles': 5027,
#                                     'n_reco': 4447,
#                                     'purityT': 99.6874215536958,
#                                     'recoeffT': 88.46230356077183},
#                                 {   'avg_hiteff': 88.64564273069428,
#                                     'avg_purity': 99.66494845360825,
#                                     'avg_recoeff': 75.23845381526104,
#                                     'clone_percentage': 10.30859049207673,
#                                     'hit_eff_percentage': 89.14756932792145,
#                                     'label': 'long',
#                                     'n_clones': 618,
#                                     'n_particles': 7968,
#                                     'n_reco': 5995,
#                                     'purityT': 99.70082392110974,
#                                     'recoeffT': 75.23845381526104},
#                                 {   'avg_hiteff': 61.77248677248678,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 73.28042328042328,
#                                     'clone_percentage': 7.9422382671480145,
#                                     'hit_eff_percentage': 89.81098797152312,
#                                     'label': 'long_strange',
#                                     'n_clones': 22,
#                                     'n_particles': 378,
#                                     'n_reco': 277,
#                                     'purityT': 99.63608854913204,
#                                     'recoeffT': 73.28042328042328}],
#                       '99': [   {   'avg_hiteff': 90.36780987212016,
#                                     'avg_purity': 99.51970443349755,
#                                     'avg_recoeff': 54.01769785199457,
#                                     'clone_percentage': 7.497192681154634,
#                                     'hit_eff_percentage': 90.48048342177218,
#                                     'label': 'velo',
#                                     'n_clones': 1135,
#                                     'n_particles': 28026,
#                                     'n_reco': 15139,
#                                     'purityT': 99.64690801231406,
#                                     'recoeffT': 54.017697851994576},
#                                 {   'avg_hiteff': 0.0,
#                                     'avg_purity': 0.0,
#                                     'avg_recoeff': 57.65765765765766,
#                                     'clone_percentage': 7.8125,
#                                     'hit_eff_percentage': 90.89633735248711,
#                                     'label': 'long_fromb',
#                                     'n_clones': 20,
#                                     'n_particles': 444,
#                                     'n_reco': 256,
#                                     'purityT': 99.21207264957266,
#                                     'recoeffT': 57.65765765765766},
#                                 {   'avg_hiteff': 0.0,
#                                     'avg_purity': 0.0,
#                                     'avg_recoeff': 61.224489795918366,
#                                     'clone_percentage': 7.142857142857143,
#                                     'hit_eff_percentage': 91.71515364595722,
#                                     'label': 'long_fromb>5GeV',
#                                     'n_clones': 15,
#                                     'n_particles': 343,
#                                     'n_reco': 210,
#                                     'purityT': 99.03347578347578,
#                                     'recoeffT': 61.224489795918366},
#                                 {   'avg_hiteff': 100.0,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 93.10344827586206,
#                                     'clone_percentage': 4.320987654320987,
#                                     'hit_eff_percentage': 94.51195747053735,
#                                     'label': 'long_strange>5GeV',
#                                     'n_clones': 7,
#                                     'n_particles': 174,
#                                     'n_reco': 162,
#                                     'purityT': 99.62242885319809,
#                                     'recoeffT': 93.10344827586206},
#                                 {   'avg_hiteff': 91.54411764705883,
#                                     'avg_purity': 99.52731092436974,
#                                     'avg_recoeff': 88.45098039215686,
#                                     'clone_percentage': 7.891819995566394,
#                                     'hit_eff_percentage': 91.54205920140073,
#                                     'label': 'long>5GeV',
#                                     'n_clones': 356,
#                                     'n_particles': 5100,
#                                     'n_reco': 4511,
#                                     'purityT': 99.6851845446976,
#                                     'recoeffT': 88.45098039215686},
#                                 {   'avg_hiteff': 89.16351010101009,
#                                     'avg_purity': 99.59821428571429,
#                                     'avg_recoeff': 75.13620604259535,
#                                     'clone_percentage': 10.299934080421885,
#                                     'hit_eff_percentage': 89.14775989305103,
#                                     'label': 'long',
#                                     'n_clones': 625,
#                                     'n_particles': 8076,
#                                     'n_reco': 6068,
#                                     'purityT': 99.6995974500457,
#                                     'recoeffT': 75.13620604259535},
#                                 {   'avg_hiteff': 77.77777777777777,
#                                     'avg_purity': 100.0,
#                                     'avg_recoeff': 73.24675324675324,
#                                     'clone_percentage': 8.156028368794326,
#                                     'hit_eff_percentage': 89.57426908246583,
#                                     'label': 'long_strange',
#                                     'n_clones': 23,
#                                     'n_particles': 385,
#                                     'n_reco': 282,
#                                     'purityT': 99.6432474629196,
#                                     'recoeffT': 73.24675324675324}]},
#         'overall_ghost_rate': 1.1993116058943745,
#         'parameters': {   'max_slopes': (0.1, 0.1),
#                           'max_tolerance': (0.1, 0.1),
#                           'scatter': 0.1},
#         'total_ghosts': 223,
#         'total_tracks': 18594}]

# %%
overall , catagory, event = output_distributions(wrapper)

# %% [markdown]
# ### Lets review data size generated

# %%
track_size = sys.getsizeof(tracks)
output_raw = sys.getsizeof(wrapper) + sys.getsizeof(results)
db1 = sys.getsizeof(overall)
db2 = sys.getsizeof(catagory)
db3 = sys.getsizeof(event)

print("{:<10} {:>10}".format("Variable", "Byte Size"))
print("{:<10} {:>10}".format("--------", "---------"))
print("{:<10} {:>10}".format("tracks", track_size))
print("{:<10} {:>10}".format("wrapper", output_raw))
print("{:<10} {:>10}".format("overall", db1))
print("{:<10} {:>10}".format("catagory", db2))
print("{:<10} {:>10}".format("event", db3))
# Out:
# Variable    Byte Size
# --------    ---------
# tracks            848
# wrapper           360
# overall           364
# catagory         2202
# event            6340

# %% [markdown]
# ## Data Generation Analysis
#
# We have **99 events** (excluding event **51**, which is corrupted) and **1 run**.
# For this analysis, we assume that there are no differences in data generation between runs and that a sample size of **99** is representative of average data collection.
#
# ### Estimation of Data Generation
#
# We estimate the data generation of each method/operation using the following equation:
#
# ```math
# n_{\text{events}} \times n_{\text{runs}} \times C_V = \text{bytes}
# ```
#
# where $C_V$ is a constant for each variable/operation. This constant can be derived by rewriting the equation as:
#
# ```math
# C_V = \frac{\text{bytes}}{99}
# ```
#
# ### Calculated Values for $C_V$
#
# | Variable  | $C_V$  |
# |-----------|--------:|
# | tracks    | **8.57**  |
# | wrapper   | **3.64**  |
# | overall   | **3.68**  |
# | category  | **22.24** |
# | event     | **64.04** |
# | **Total DB output** | **89.96** |
#
# This table represents the constant $C_V$ values calculated for different variables.
